# %% [markdown]
# <center><img src="https://d4x5p7s4.rocketcdn.me/wp-content/uploads/2016/03/logo-poster-smaller.png"/> </center>
#
#
# # Installation of the data science libraries
#
# In this exercise, we will ensure that our environment has all the necessary libraries installed. If you are not using the VM provided for the workshop, then download and install the latest version of `anaconda` python distribution onto your workstation (or the cloud VM instance that you are using).
#
# After that, pull the relevant git repository from the supportvectors github site 'data-wrangling-v2'. This current notebook belongs to that repository. Once you have fired up the `jupyter notebook` and navigated to the directory where you have cloned the repository, open the notebook `DW-Lesson-0__libraries_installation.ipynb`.
#
# ## Steps
#
# **Caveat Emptor** Run the following cells only once on a given workstation; it is *not* necessary to run it everytime you start your jupyter environment. If you are using the SupportVectors VM, then it has already been done for you, so you can skip the below exercise altogether.
#
# ### Step 0
#
# Mark this notebook as trusted, by clicking the `Not Trusted` button near the top-right of the notebook.

# %% [markdown]
# ### Step 1
#
# Mark the notebooks in the directory as trusted. This is essential, otherwise, you will have to re-execute the entire notebook to see all the plots, etc. sometimes.

# %%
! ./trust.sh
# Out:
# Marking as trusted: chunkingexprts.ipynb
# Notebook already signed: chunkingexprts.ipynb
# Marking as trusted: elastic-search-notes.ipynb
# Notebook already signed: elastic-search-notes.ipynb
# Marking as trusted: elastic-search-notes_original.ipynb
# Notebook already signed: elastic-search-notes_original.ipynb
# Marking as trusted: full_NLP-Lesson-01___semantic-search.ipynb
# Notebook already signed: full_NLP-Lesson-01___semantic-search.ipynb
# Marking as trusted: NLP-Lesson-00a___libraries_installation.ipynb
# Signing notebook: NLP-Lesson-00a___libraries_installation.ipynb
# Marking as trusted: NLP-Lesson-00b___visualization_libraries_installation.ipynb
# Signing notebook: NLP-Lesson-00b___visualization_libraries_installation.ipynb
# Marking as trusted: NLP-Lesson-00c___nlp_libraries_installation.ipynb
# Signing notebook: NLP-Lesson-00c___nlp_libraries_installation.ipynb
# Marking as trusted: NLP-Lesson-01___search-corpus.ipynb
# Notebook already signed: NLP-Lesson-01___search-corpus.ipynb
# Marking as trusted: NLP-Lesson-01___semantic-search.ipynb
# Notebook already signed: NLP-Lesson-01___semantic-search.ipynb
# Marking as trusted: NLP-Lesson-02___huggingface_intro_with_sentiment.ipynb
# Notebook already signed: NLP-Lesson-02___huggingface_intro_with_sentiment.ipynb
# Marking as trusted: NLP-Lesson-03___zero_shot_classifier-Copy1.ipynb
# Notebook already signed: NLP-Lesson-03___zero_shot_classifier-Copy1.ipynb
# Marking as trusted: NLP-Lesson-03___zero_shot_classifier.ipynb
# Notebook already signed: NLP-Lesson-03___zero_shot_classifier.ipynb
# Marking as trusted: NLP-Lesson-04___text_generation.ipynb
# Notebook already signed: NLP-Lesson-04___text_generation.ipynb
# Marking as trusted: NLP-Lesson-05___text_to_image.ipynb
# Notebook already signed: NLP-Lesson-05___text_to_image.ipynb
# Marking as trusted: NLP-Lesson-06___ner.ipynb
# Notebook already signed: NLP-Lesson-06___ner.ipynb
# Marking as trusted: NLP-Lesson-07___visual_qa.ipynb
# Notebook already signed: NLP-Lesson-07___visual_qa.ipynb
# Marking as trusted: NLP-Lesson-08___pretrained.ipynb
# Notebook already signed: NLP-Lesson-08___pretrained.ipynb
# Marking as trusted: NLP-Lesson-08___transfer_learning.ipynb
# Notebook already signed: NLP-Lesson-08___transfer_learning.ipynb
# Marking as trusted: NLP-Lesson-09___autoclass.ipynb
# Notebook already signed: NLP-Lesson-09___autoclass.ipynb
# Marking as trusted: NLP-Lesson-10___tokenizers.ipynb
# Notebook already signed: NLP-Lesson-10___tokenizers.ipynb
# Marking as trusted: NLP-Lesson-11___datasets.ipynb
# Notebook already signed: NLP-Lesson-11___datasets.ipynb
# Marking as trusted: NLP-Lesson-12___autoclassifier.ipynb
# Notebook already signed: NLP-Lesson-12___autoclassifier.ipynb
# Marking as trusted: NLP-Lesson-13___carbon-emissions.ipynb
# Notebook already signed: NLP-Lesson-13___carbon-emissions.ipynb
# Marking as trusted: NLP-Lesson-14___social-biases.ipynb
# Notebook already signed: NLP-Lesson-14___social-biases.ipynb
# Marking as trusted: NLP-Lesson-15___fine-tuning.ipynb
# Notebook already signed: NLP-Lesson-15___fine-tuning.ipynb
# Marking as trusted: NLP-Lesson-16___langchain_basics.ipynb
# Notebook already signed: NLP-Lesson-16___langchain_basics.ipynb
# Marking as trusted: NLP-Lesson-17___langchain_prompts.ipynb
# Notebook already signed: NLP-Lesson-17___langchain_prompts.ipynb
# Marking as trusted: NLP-Lesson-18__langchain_tools
# [TrustNotebookApp] ERROR | Notebook missing: NLP-Lesson-18__langchain_tools
# Marking as trusted: (1).ipynb
# [TrustNotebookApp] ERROR | Notebook missing: (1).ipynb
# Marking as trusted: NLP-Lesson-18__langchain_tools.ipynb
# Notebook already signed: NLP-Lesson-18__langchain_tools.ipynb
# Marking as trusted: NLP-Lesson-19___database_queries.ipynb
# Notebook already signed: NLP-Lesson-19___database_queries.ipynb
# Marking as trusted: NLP-Lesson-20___qa.ipynb
# Notebook already signed: NLP-Lesson-20___qa.ipynb
# Marking as trusted: NLP-Lesson-21___speech_transcription.ipynb
# Notebook already signed: NLP-Lesson-21___speech_transcription.ipynb
# Marking as trusted: postgreslibcopy.ipynb
# Notebook already signed: postgreslibcopy.ipynb
# Marking as trusted: semantic_chunking.ipynb
# Traceback (most recent call last):
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/reader.py", line 20, in parse_json
#     nb_dict = json.loads(s, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/shaanvi/anaconda3/bin/jupyter-trust", line 11, in <module>
#     sys.exit(TrustNotebookApp.launch_instance())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/jupyter_core/application.py", line 277, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/sign.py", line 638, in start
#     self.sign_notebook_file(notebook_path)
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/sign.py", line 606, in sign_notebook_file
#     nb = read(f, NO_CONVERT)
#          ^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/__init__.py", line 171, in read
#     return reads(buf, as_version, capture_validation_error, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/__init__.py", line 89, in reads
#     nb = reader.reads(s, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/reader.py", line 76, in reads
#     nb_dict = parse_json(s, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/shaanvi/anaconda3/lib/python3.11/site-packages/nbformat/reader.py", line 26, in parse_json
#     raise NotJSONError(message) from e
# nbformat.reader.NotJSONError: Notebook does not appear to be JSON: '<!DOCTYPE HTML>\n<html>\n\n<head>\n    ...
# Marking as trusted: semanticchunking.ipynb
# Notebook already signed: semanticchunking.ipynb
# Marking as trusted: supportvectors-common.ipynb
# Notebook already signed: supportvectors-common.ipynb
# Marking as trusted: trim_NLP-Lesson-01___semantic-search.ipynb
# Notebook already signed: trim_NLP-Lesson-01___semantic-search.ipynb
# Marking as trusted: TryingRAG.ipynb
# Notebook already signed: TryingRAG.ipynb
# Marking as trusted: understandingchunks.ipynb
# Notebook already signed: understandingchunks.ipynb
# Marking as trusted: Untitled1.ipynb
# Notebook already signed: Untitled1.ipynb
# Marking as trusted: Untitled2.ipynb
# Notebook already signed: Untitled2.ipynb
# Marking as trusted: Untitled3.ipynb
# Notebook already signed: Untitled3.ipynb
# Marking as trusted: Untitled4.ipynb
# Notebook already signed: Untitled4.ipynb
# Marking as trusted: Untitled5.ipynb
# Notebook already signed: Untitled5.ipynb
# Marking as trusted: Untitled6.ipynb
# Notebook already signed: Untitled6.ipynb
# Marking as trusted: Untitled7.ipynb
# Notebook already signed: Untitled7.ipynb
# Marking as trusted: Untitled9.ipynb
# Notebook already signed: Untitled9.ipynb
# Marking as trusted: Untitled.ipynb
# Notebook already signed: Untitled.ipynb

# %% [markdown]
# ### Step 2
#
# Run the following cell to install the libraries we need for this workshop, and/or ensure that they are the latest versions.

# %%
# !pip install  --upgrade -r requirements.txt --user
# Out:
# WARNING: Skipping /home/shaanvi/anaconda3/lib/python3.11/site-packages/torchvision-0.15.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/shaanvi/anaconda3/lib/python3.11/site-packages/torchvision-0.15.2.dist-info due to invalid metadata entry 'name'
# DEPRECATION: Loading egg at /home/shaanvi/anaconda3/lib/python3.11/site-packages/svlearn_bootcamp-1.0.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: numpy in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.24.4)
# Collecting numpy (from -r requirements.txt (line 1))
#   Using cached numpy-1.26.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: scipy in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.11.3)
# Requirement already satisfied: pandas in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.1.1)
# Collecting pandas (from -r requirements.txt (line 3))
#   Downloading pandas-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: sklearn in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.0.post10)
# Collecting sklearn (from -r requirements.txt (line 4))
#   Using cached sklearn-0.0.post11.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: yellowbrick in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.5)
# Requirement already satisfied: matplotlib in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: seaborn in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.13.0)
# Requirement already satisfied: altair in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (5.1.2)
# Requirement already satisfied: plotly in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (5.18.0)
# Requirement already satisfied: pandas_bokeh in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (0.5.5)
# Requirement already satisfied: streamlit in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (1.27.2)
# Collecting streamlit (from -r requirements.txt (line 11))
#   Downloading streamlit-1.28.1-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: ipyplot in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (1.1.1)
# Requirement already satisfied: jupyter_contrib_nbextensions in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: spacy in /home/shaanvi/.local/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from yellowbrick->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: cycler>=0.10.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from yellowbrick->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pillow>=8 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: jinja2 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from altair->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from altair->-r requirements.txt (line 8)) (4.17.3)
# Requirement already satisfied: toolz in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from altair->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from plotly->-r requirements.txt (line 9)) (8.2.3)
# Requirement already satisfied: bokeh>=2.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from pandas_bokeh->-r requirements.txt (line 10)) (3.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (6.0.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (4.21.12)
# Requirement already satisfied: pyarrow>=6.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (13.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (13.6.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (4.7.1)
# Requirement already satisfied: tzlocal<6,>=1.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (5.1)
# Requirement already satisfied: validators<1,>=0.2 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/shaanvi/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 11)) (2.1.6)
# Requirement already satisfied: IPython in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from ipyplot->-r requirements.txt (line 12)) (8.15.0)
# Requirement already satisfied: shortuuid in /home/shaanvi/.local/lib/python3.11/site-packages (from ipyplot->-r requirements.txt (line 12)) (1.0.11)
# Requirement already satisfied: ipython-genutils in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /home/shaanvi/.local/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: jupyter-core in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (5.3.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: nbconvert>=6.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (6.5.4)
# Requirement already satisfied: notebook>=6.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (6.5.4)
# Requirement already satisfied: traitlets>=4.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (5.7.1)
# Requirement already satisfied: lxml in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (4.9.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (0.3.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (1.10.13)
# Requirement already satisfied: setuptools in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (68.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from spacy->-r requirements.txt (line 14)) (3.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from bokeh>=2.0->pandas_bokeh->-r requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from bokeh>=2.0->pandas_bokeh->-r requirements.txt (line 10)) (2022.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 11)) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from importlib-metadata<7,>=1.4->streamlit->-r requirements.txt (line 11)) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jinja2->altair->-r requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair->-r requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair->-r requirements.txt (line 8)) (0.18.0)
# Requirement already satisfied: beautifulsoup4 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (4.12.2)
# Requirement already satisfied: bleach in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (4.1.0)
# Requirement already satisfied: defusedxml in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (2.15.1)
# Requirement already satisfied: tinycss2 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter-core->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (3.10.0)
# Requirement already satisfied: pyzmq>=17 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (23.2.0)
# Requirement already satisfied: argon2-cffi in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.5.8)
# Requirement already satisfied: ipykernel in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (6.25.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.17.1)
# Requirement already satisfied: prometheus-client in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.5.5)
# Requirement already satisfied: six>=1.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 11)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 11)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 11)) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 11)) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 11)) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->yellowbrick->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->yellowbrick->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/shaanvi/.local/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy->-r requirements.txt (line 14)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy->-r requirements.txt (line 14)) (0.1.3)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy->-r requirements.txt (line 14)) (0.15.1)
# Requirement already satisfied: backcall in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: decorator in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (0.1.6)
# Requirement already satisfied: pickleshare in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (3.0.36)
# Requirement already satisfied: stack-data in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from IPython->ipyplot->-r requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/shaanvi/.local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 11)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->IPython->ipyplot->-r requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 11)) (0.1.0)
# Requirement already satisfied: jupyter-server>=1.8 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: fastjsonschema in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->IPython->ipyplot->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->ipyplot->-r requirements.txt (line 12)) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (2.4)
# Requirement already satisfied: webencodings in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: comm>=0.1.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.6.7)
# Requirement already satisfied: psutil in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (5.9.0)
# Requirement already satisfied: executing in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from stack-data->IPython->ipyplot->-r requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: asttokens in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from stack-data->IPython->ipyplot->-r requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: pure-eval in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from stack-data->IPython->ipyplot->-r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/shaanvi/.local/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (3.7.1)
# Requirement already satisfied: websocket-client in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: pycparser in /home/shaanvi/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 13)) (2.21)
# Downloading numpy-1.26.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 28.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading pandas-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 33.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading streamlit-1.28.1-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 33.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post11-py3-none-any.whl size=2959 sha256=c06282bb317e4ead794b4b1aead1f2427fa25303d8ae8f42f235736a74680d7d
#   Stored in directory: /home/shaanvi/.cache/pip/wheels/52/cc/47/500a56407c060a5d18bda9aa3ec2daf4721b8448ee4b268840
# Successfully built sklearn
# WARNING: Skipping /home/shaanvi/anaconda3/lib/python3.11/site-packages/torchvision-0.15.2.dist-info due to invalid metadata entry 'name'
# Installing collected packages: sklearn, numpy, pandas, streamlit
#   Attempting uninstall: sklearn
#     Found existing installation: sklearn 0.0.post10
#     Uninstalling sklearn-0.0.post10:
#       Successfully uninstalled sklearn-0.0.post10
#   WARNING: The script f2py is installed in '/home/shaanvi/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.1
#     Uninstalling pandas-2.1.1:
#       Successfully uninstalled pandas-2.1.1
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.27.2
#     Uninstalling streamlit-1.27.2:
#       Successfully uninstalled streamlit-1.27.2
#   WARNING: The script streamlit is installed in '/home/shaanvi/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# xformers 0.0.20 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.1 which is incompatible.
# Successfully installed numpy-1.26.1 pandas-2.1.3 sklearn-0.0.post11 streamlit-1.28.1
# WARNING: Skipping /home/shaanvi/anaconda3/lib/python3.11/site-packages/torchvision-0.15.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/shaanvi/anaconda3/lib/python3.11/site-packages/torchvision-0.15.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/shaanvi/anaconda3/lib/python3.11/site-packages/torchvision-0.15.2.dist-info due to invalid metadata entry 'name'

# %% [markdown]
# ### Step 3
#
# Now, it is time to copy the jupyter notebook extensions javascript and css files into the relevant locations.

# %%
# %%capture
# !jupyter contrib nbextension install --user

# %% [markdown]
# Now, your environment should be ready for this workshop. **Bon Voyage!**
