# %%
# %run supportvectors-common.ipynb
# Out:
# <!-- Many of the styles here are inspired by:
#     https://towardsdatascience.com/10-practical-tips-you-need-to-know-to-personalize-jupyter-notebook-fbd202777e20
#
#
#     On the author's local machine, these exist in the custom.css file. However, in order to keep uniform look and feel,
#     and at the request of participants, I have added it to this common import-file here.
#
#     -->
#
# <link href="https://fonts.googleapis.com/css?family=Lora:400,700|Montserrat:300" rel="stylesheet">
#
# <link href="https://fonts.googleapis.com/css2?family=Crimson+Pro&family=Literata&display=swap" rel="stylesheet">
# <style>
#
#
# #ipython_notebook::before{
#  content:"Data Wrangling";
#         color: white;
#         font-weight: bold;
#         text-transform: uppercase;
#         font-family: 'Lora',serif;
#         font-size:16pt;
#         margin-bottom:15px;
#
# }
# body > #header {
#     #background: #D15555;
#     background: linear-gradient(to bottom, indianred 0%, #fff 100%);
#     opacity: 0.8;
#
# }
#
#
# .navbar-default .navbar-nav > li > a, #kernel_indicator {
#     color: white;
#     transition: all 0.25s;
#     font-size:12pt;
#     font-family: sans;
#     font-weight:bold;
# }
# .navbar-default {
#     padding-left:100px;
#     background: none;
#     border: none;
# }
#
#
# body > menubar-container {
#     background-color: wheat;
# }
# #ipython_notebook img{
#     display:block;
#
#     background: url("https://www.supportvectors.com/wp-content/uploads/2016/03/logo-poster-smaller.png") no-repeat;
#     background-size: contain;
#
#     padding-left: 600px;
#     padding-right: 100px;
#
#     -moz-box-sizing: border-box;
#     box-sizing: border-box;
# }
#
#
#
# body {
#  #font-family:  'Literata', serif;
#     font-family:'Lora', san-serif;
#     text-align: justify;
#     font-weight: 400;
#     font-size: 12pt;
# }
#
# iframe{
#     width:100%;
#     min-height:600px;
# }
#
# h1, h2, h3, h4, h5, h6 {
# # font-family: 'Montserrat', sans-serif;
#  font-family:'Lora', serif;
#  font-weight: 200;
#  text-transform: uppercase;
#  color: #EC7063 ;
# }
#
# h2 {
#     color: #000080;
# }
#
# .checkpoint_status, .autosave_status {
#     color:wheat;
# }
#
# #notebook_name {
#     font-weight: 1000;
#     font-size:20pt;
#     text-variant:uppercase;
#     color: wheat;
#     margin-right:20px;
# }
# #notebook_name:hover {
# background-color: salmon;
# }
#
#
# .dataframe { /* dataframe atau table */
#     background: white;
#     box-shadow: 0px 1px 2px #bbb;
# }
# .dataframe thead th, .dataframe tbody td {
#     text-align: center;
#     padding: 1em;
# }
#
# .checkpoint_status, .autosave_status {
#     color:wheat;
# }
#
# .output {
#     align-items: center;
# }
#
# div.cell {
#     transition: all 0.25s;
#     border: none;
#     position: relative;
#     top: 0;
# }
# div.cell.selected, div.cell.selected.jupyter-soft-selected {
#     border: none;
#     background: transparent;
#     box-shadow: 0 6px 18px #aaa;
#     z-index: 10;
#     top: -10px;
# }
# .CodeMirror pre, .CodeMirror-dialog, .CodeMirror-dialog .CodeMirror-search-field, .terminal-app .terminal {
#     font-family: 'Hack' , serif;
#     font-weight: 600;
#     font-size: 14pt;
# }
#
#
#
# </style>

# %% [markdown]
# # Split Apply Combine
#
# ## Lesson Goals
#
# In this lesson we will learn about one of the most powerful idioms in data wrangling, which systematically solve a larger problem by dividing the dataset, applying separate transformations to the parts, and then recombining or aggregating the parts into a new whole.
#
# In particular, this discussion follows along the work of Hadley Wickham, in his influential and much cited article:
#
# <a href="https://www.researchgate.net/publication/51028554_The_Split-Apply-Combine_Strategy_for_Data_Analysis"> **"The Split-Apply-Combine Strategy for Data Analysis"**. </a>
#
#
# ## Introduction
#
# What is `split-apply-combine`?
#
# `split-apply-combine` is a common data analysis strategy used whenever a big problem needs to be  broken into smaller manageable pieces, operated on each piece separately and then put all the pieces back together.
#
# * **Splitting** the data into groups based on some criteria.
#
# * **Applying** a function to each group independently.
#
# * **Combining** the results into a data structure.
#
# Some of the common uses of this strategy are:
#
# 1. Data preparation - group wise ranking, standardization, normalization, or creating new variables
# 2. Creating summaries for analysis/display
# 3. Modeling: Fit separate models to different groups of data
#
#
# ## `split-apply-combine` with Pandas
#
# In Pandas,  `split-apply-combine` is done using `DataFrame.groupby()`.The user-guide of pandas has a detailed section on the `groupby()`.(See references at the end of this lesson.)
#
# Let's import all the necessary libraries first.

# %%
import pandas as pd
import numpy as np

# paths to the most commonly used dataset repositories for this lab

# path to pandas_for_everyone datasets repository
pfe_rep_path = 'https://raw.githubusercontent.com/chendaniely/pandas_for_everyone/master/data/'

# path to SupportVectors data-wrangling-datasets repository
sv_rep_path = 'https://raw.githubusercontent.com/supportvectors/data-wrangling-datasets/main/'

# %% [markdown]
# ## Splitting an object into groups
#
# Let's create a dataframe and use the groupby method to see how it works

# %%
df = pd.DataFrame({
    'key': ['X', 'Y', 'Z', 'X', 'Y', 'Z', 'X', 'Y', 'Z'],
    'value': range(9),
}, columns = ['key', 'value'])

df
# Out:
#   key  value
# 0   X      0
# 1   Y      1
# 2   Z      2
# 3   X      3
# 4   Y      4
# 5   Z      5
# 6   X      6
# 7   Y      7
# 8   Z      8

# %% [markdown]
# The groupby object is created using the `.groupby()` method

# %%
groups = df.groupby('key')
groups

# %% [markdown]
# We see that `groups` above points to special kind of object, `DataFrameGroupBy`.
#
# The `groupby()` method splits the data frame into groups based on a the key column/row specified and stores it as a `DataFrameGroupBy` object, that somewhat behaves like a iterable map from group-name to its own partition of the data, (as a dataframe itself). The groups can be accessed by:
#
# * iterating over the `groupby` object
# * or by using the `get_group()` method.

# %%
for name, group in groups:
    print(f'Group name: {name}')
    print (f'\nThe partition of the data in this group: \n {group}')
# Out:
# Group name: X
#
# The partition of the data in this group:
#    key  value
# 0   X      0
# 3   X      3
# 6   X      6
# Group name: Y
#
# The partition of the data in this group:
#    key  value
# 1   Y      1
# 4   Y      4
# 7   Y      7
# Group name: Z
#
# The partition of the data in this group:
#    key  value
# 2   Z      2
# 5   Z      5
# 8   Z      8

# %%
groups.get_group("Z")
# Out:
#   key  value
# 2   Z      2
# 5   Z      5
# 8   Z      8

# %% [markdown]
# ## Apply functions
#
# Once the GroupBy object has been created, several methods are available to perform a computation on the grouped data
#
# 1. Aggregation: Compute a summary statistic (or statistics) for each group.
#
# 2. Transformation: Perform some group-specific computations and return a like-indexed object i.e. a table of the same dimension.
#
# 3. Filteration:  Discard some groups, according to a group-wise computation that evaluates True or False.

# %% [markdown]
# ## Aggregation
#
# It is also known as summarization. An aggregation is takes a collection of values, and extracts from it some meaningful quantifier or statistical descriptor, such as *sum*, *mean*, etc.In other words, aggregation is a many to one operation or function.
#
# To those familiar with functional programming, `agg()` behaves like the `reduce()` in the `map-reduce` idiom.
#
#
# ![split_apply_combine_agg.PNG](attachment:split_apply_combine_agg.PNG)

# %%
groups = df.groupby('key').mean()
groups
# Out:
#      value
# key
# X      3.0
# Y      4.0
# Z      5.0

# %% [markdown]
# ## Gapminder dataset
#
#
# Website https://www.gapminder.org/ Gapminder is an independent Swedish foundation with no political, religious, or economic affiliations.
#
# We further explore the dataset we tidied up in our "Health and Wealth of Nations" homework.
#
# The semantics of the gapminder dataset: Each observation is a record of the population, life expectancy and income of each country of each continent for the years ranging from 1800-2050.
#
# The dataset is tidy and it is recommended to be so in order to perform split-apply-combine strategies. Let's load this dataset from the SupportVectors repository.

# %%
source = sv_rep_path + 'gapminder_dataset.csv'
gapminder = pd.read_csv(source)
gapminder.drop("Unnamed: 0", axis=1,inplace=True)
gapminder
# Out:
#            country  year         pop  income  lifeExp Continent
# 0      Afghanistan  1800   3280000.0   674.0     28.2      Asia
# 1      Afghanistan  1801   3280000.0   674.0     28.2      Asia
# 2      Afghanistan  1802   3280000.0   674.0     28.2      Asia
# 3      Afghanistan  1803   3280000.0   674.0     28.2      Asia
# 4      Afghanistan  1804   3280000.0   674.0     28.2      Asia
# ...            ...   ...         ...     ...      ...       ...
# 46681     Zimbabwe  2046  22800000.0  3880.0     66.9    Africa
# 46682     Zimbabwe  2047  23100000.0  3960.0     67.1    Africa
# 46683     Zimbabwe  2048  23400000.0  4050.0     67.3    Africa
# 46684     Zimbabwe  2049  23700000.0  4130.0     67.4    Africa
# 46685     Zimbabwe  2050  23900000.0  4220.0     67.6    Africa
#
# [46686 rows x 6 columns]

# %% [markdown]
# ### basic one variable aggregation
#
# Goal: Compute the mean life expectancy for each year in the dataset.
#
# To compute for an individual year we can filter the data by boolean subsetting. To compute the mean for all the years, we use the groupby method. Note the length of the combined output.

# %%
gapminder.groupby('year').lifeExp.mean()
# Out:
# year
# 1800    31.503763
# 1801    31.463441
# 1802    31.480108
# 1803    31.385484
# 1804    31.460753
#           ...
# 2046    77.497312
# 2047    77.643011
# 2048    77.795161
# 2049    77.932796
# 2050    78.075269
# Name: lifeExp, Length: 251, dtype: float64

# %% [markdown]
# There are several methods that can be used with GroupBy Objects.
# Built-in aggregation methods:
#
# * count
# * size
# * mean
# * std
# * min
# * quantile
# * max
# * sum
# * var
# * sem
# * describe
# * first
# * last
# * nth
#
# documentation: https://pandas.pydata.org/docs/reference/groupby.html#computations-descriptive-stats

# %% [markdown]
# ### .agg method
#
# Apart from the built in functions one may create custom functions that take a series as input and returns a value. These functions can be passed to the `.agg()` function.

# %%
def my_func(series):
    return (series.max() - series.min())/series.count()

gapminder.groupby('year').lifeExp.agg(my_func)
# Out:
# year
# 1800    0.104839
# 1801    0.090860
# 1802    0.112903
# 1803    0.135484
# 1804    0.104301
#           ...
# 2046    0.153226
# 2047    0.152151
# 2048    0.151613
# 2049    0.151075
# 2050    0.150538
# Name: lifeExp, Length: 251, dtype: float64

# %% [markdown]
# ### multiple functions on one column
#
# One can aggregate using multiple functions using the .agg() method

# %%
gapminder.groupby('year').lifeExp.agg([my_func, 'mean', np.std, np.var])
# Out:
#        my_func       mean       std        var
# year
# 1800  0.104839  31.503763  3.809510  14.512364
# 1801  0.090860  31.463441  3.801217  14.449251
# 1802  0.112903  31.480108  3.932344  15.463332
# 1803  0.135484  31.385484  3.955872  15.648923
# 1804  0.104301  31.460753  3.928388  15.432235
# ...        ...        ...       ...        ...
# 2046  0.153226  77.497312  6.186773  38.276155
# 2047  0.152151  77.643011  6.171231  38.084086
# 2048  0.151613  77.795161  6.160013  37.945760
# 2049  0.151075  77.932796  6.144956  37.760486
# 2050  0.150538  78.075269  6.134116  37.627385
#
# [251 rows x 4 columns]

# %% [markdown]
# ### Single function on multiple columns
#
# If the selected aggregate function does not suit the column, then it is dropped

# %%
gapminder.groupby(['year', 'Continent'] ).mean()
# Out:
#                              pop        income    lifeExp
# year Continent
# 1800 Africa         1.503322e+06    696.814815  30.525926
#      Asia           1.515597e+07   1039.170213  29.670213
#      Europe         3.949462e+06   1519.023810  35.430952
#      North America  6.784952e+05   1121.857143  31.100000
#      Oceania        1.471100e+05    771.000000  28.020000
# ...                          ...           ...        ...
# 2050 Asia           1.150105e+08  41275.106383  79.402128
#      Europe         1.411650e+07  70745.238095  83.183333
#      North America  3.292948e+07  32530.476190  79.966667
#      Oceania        5.624400e+06  22817.000000  72.990000
#      South America  4.091208e+07  25180.000000  80.816667
#
# [1506 rows x 3 columns]

# %% [markdown]
# ### Aggregate by column specific functions
#
# So far we've aggregated values of a single column. We may be interested to do so on multiple columns. For example to know the `mean`, `min` and `max` life expectancy of a `continent` on a particular `year`

# %%
gapminder.groupby(['year', 'Continent'] ).agg({'pop': 'mean', 'income': 'median', 'lifeExp': 'max'})
# Out:
#                              pop   income  lifeExp
# year Continent
# 1800 Africa         1.503322e+06    642.0     37.0
#      Asia           1.515597e+07   1020.0     36.4
#      Europe         3.949462e+06   1410.0     42.9
#      North America  6.784952e+05    977.0     39.4
#      Oceania        1.471100e+05    697.5     34.0
# ...                          ...      ...      ...
# 2050 Asia           1.150105e+08  26400.0     88.6
#      Europe         1.411650e+07  68050.0     88.0
#      North America  3.292948e+07  25700.0     86.2
#      Oceania        5.624400e+06   8385.0     86.6
#      South America  4.091208e+07  24400.0     86.5
#
# [1506 rows x 3 columns]

# %% [markdown]
# ## transform
#
# Transform is an operation used in conjunction with `groupby()`. It performs some group-specific computations and returns a like-indexed object. It does a one-to-one transformation. Data is not reduced. The image below illustrates this concept.
#
# *Note*: To those familiar with functional programming, `transform()` behaves like the `map()` in the `map-reduce` idiom. When put together with `groupby()` for a dataframe, then the conjunction `groupby(...).transform(....)` behaves like the `groupByKey(...)` followed by a mapping function. Note that doing so restores the original (ungrouped) number of rows. It is the illustration of 'split-transform-combine'.
#
# ![split_apply_combine_transform.PNG](attachment:split_apply_combine_transform.PNG)
#
# We can compare aggregate and transform. Note the shape of the returned dataframes

# %%
gapminder.groupby('year').lifeExp.agg('mean')
# Out:
# year
# 1800    31.503763
# 1801    31.463441
# 1802    31.480108
# 1803    31.385484
# 1804    31.460753
#           ...
# 2046    77.497312
# 2047    77.643011
# 2048    77.795161
# 2049    77.932796
# 2050    78.075269
# Name: lifeExp, Length: 251, dtype: float64

# %%
gapminder.groupby('year').lifeExp.transform('mean')
# Out:
# 0        31.503763
# 1        31.463441
# 2        31.480108
# 3        31.385484
# 4        31.460753
#            ...
# 46681    77.497312
# 46682    77.643011
# 46683    77.795161
# 46684    77.932796
# 46685    78.075269
# Name: lifeExp, Length: 46686, dtype: float64

# %% [markdown]
# ### Goal: What is the proportional income of each continent for each year in the gapminder dataset?
#
# We do this in two steps:
# 1. Split by `['year', 'Continent']` aggregate Apply - sum and combine by aggregating
# 2. Split by `['year']` transform Apply - x/x.sum()
#
# #### Aggregate

# %%
continents_gdp = gapminder.groupby(['year', 'Continent']).income.sum()
continents_gdp
# Out:
# year  Continent
# 1800  Africa             37628.0
#       Asia               48841.0
#       Europe             63799.0
#       North America      23559.0
#       Oceania             7710.0
#                          ...
# 2050  Asia             1939930.0
#       Europe           2971300.0
#       North America     683140.0
#       Oceania           228170.0
#       South America     302160.0
# Name: income, Length: 1506, dtype: float64

# %% [markdown]
# #### Transform
# The combined dataframe has multiple -indices. Let's flatten it out with `.reset_index()` method.

# %%
continents_gdp = continents_gdp.reset_index()
continents_gdp
# Out:
#       year      Continent     income
# 0     1800         Africa    37628.0
# 1     1800           Asia    48841.0
# 2     1800         Europe    63799.0
# 3     1800  North America    23559.0
# 4     1800        Oceania     7710.0
# ...    ...            ...        ...
# 1501  2050           Asia  1939930.0
# 1502  2050         Europe  2971300.0
# 1503  2050  North America   683140.0
# 1504  2050        Oceania   228170.0
# 1505  2050  South America   302160.0
#
# [1506 rows x 3 columns]

# %% [markdown]
# Next we want the proportion of the total gdp contributed by each continent for which the transform method is used.
#
# We pass a custom function that calculates the proportion groupwise. Note that in the lambda function, x refers to a series of values.
#
# `lambda x: x/x.sum()` is equivalent to `pd.Series  = pd.Series/ pd.Series.sum()`
#
# Therefore the operations are automatically aligned and vectorized.

# %%
continents_gdp['prop_gdp'] = continents_gdp.groupby(['year']).transform(lambda x: x/x.sum())
continents_gdp
# Out:
#       year      Continent     income  prop_gdp
# 0     1800         Africa    37628.0  0.191457
# 1     1800           Asia    48841.0  0.248510
# 2     1800         Europe    63799.0  0.324619
# 3     1800  North America    23559.0  0.119872
# 4     1800        Oceania     7710.0  0.039230
# ...    ...            ...        ...       ...
# 1501  2050           Asia  1939930.0  0.291772
# 1502  2050         Europe  2971300.0  0.446893
# 1503  2050  North America   683140.0  0.102747
# 1504  2050        Oceania   228170.0  0.034318
# 1505  2050  South America   302160.0  0.045446
#
# [1506 rows x 4 columns]

# %% [markdown]
# ### Chaining functions
#
# We can chain functions without resetting index as shown below:

# %%
gapminder.groupby(['year', 'Continent']).income.sum().groupby(['year']).transform(lambda x: x/x.sum())
# Out:
# year  Continent
# 1800  Africa           0.191457
#       Asia             0.248510
#       Europe           0.324619
#       North America    0.119872
#       Oceania          0.039230
#                          ...
# 2050  Asia             0.291772
#       Europe           0.446893
#       North America    0.102747
#       Oceania          0.034318
#       South America    0.045446
# Name: income, Length: 1506, dtype: float64

# %% [markdown]
# ### Graphs to Visualize the GroupBy Data

# %% [markdown]
# Now let's view the resulting information in a cool interactive visualization. Note the slider bar to change the year. You can learn more about creating visualizations like this in the SupportVectors Data Visualization Workshop.

# %%
import altair as alt

slider = alt.binding_range(name='Year:', 
                           min=1800, 
                           max=2050, 
                           step=1
                          )
selector = alt.selection_single(name="selector", 
                                fields=['year'],
                                bind=slider,
                                init={"year": 1800}
                               )

alt.Chart(continents_gdp).mark_bar().encode(
    x=alt.X(field="prop_gdp",
            title="Proportion of Total GDP Per Continent",
            type="quantitative"
                   ),
    y=alt.Y(field="Continent"),
    color=alt.Color(field="Continent",
                    type="nominal", 
                   )
    
).properties(
    height=400,
    width=800
).add_selection(selector).transform_filter(selector)
# Out:
# alt.Chart(...)

# %% [markdown]
# We can use groups to create visualizations

# %%
import matplotlib.pyplot as plt

num_axes = len(continents_gdp['Continent'].unique())    # ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

fig = plt.figure(figsize=(10,25))                       # set figure size
grouped = continents_gdp.groupby('year')                # groupby year

theta = np.radians([(30 + x*(360/num_axes))%360 for x in range(num_axes+1)])     

for idx,(year,group) in enumerate(grouped):
    if year==2030:
        break
    ax=plt.subplot(26,10, idx+1, projection='polar')
    r = group.prop_gdp.values
    r = np.append(r, r[0])
    
    ax.plot(theta, r , lw=0.5)
    ax.fill_between(theta, r, alpha=0.4)
    ax.grid( color='k', alpha=0.5, lw=0.3)
    ax.set_facecolor('white')
    ax.set_xticks(theta)
    ax.set_xticklabels([])                     # removing xticks
    ax.set_yticklabels([])
    ax.set_title(year, size=8)
    # removing yticks
    # ax.set_xlabel(name)
# plt.suptitle("Proportional income of continents from 1800-2030", size=12)

# %%
num_axes = len(continents_gdp['Continent'].unique())
np.radians([(30 + x*(360/num_axes))%360 for x in range(num_axes+1)])
# Out:
# array([0.52359878, 1.57079633, 2.61799388, 3.66519143, 4.71238898,
#        5.75958653, 0.52359878])

# %% [markdown]
# ## Apply
# Split-apply combine strategy is not limited to transform/aggregate or filter. Custom functions can be used as well.
#
# ### Goal: For each year, what are the countries that have a GDP in the 90th percentile?
#
# Lets transform and filter our data to reveal this information.

# %%
# groupby year and create a new series q90 which contains the 90th percentile income for that year.
q90 = gapminder.groupby(['year'])['income'].transform(lambda x: x.quantile(0.9))
q90
# Out:
# 0         1685.0
# 1         1660.0
# 2         1660.0
# 3         1665.0
# 4         1685.0
#           ...
# 46681    78650.0
# 46682    80350.0
# 46683    82050.0
# 46684    83800.0
# 46685    85550.0
# Name: income, Length: 46686, dtype: float64

# %%
# filter the data to 
gapminder_rich = gapminder[gapminder['income'] >= q90]
gapminder_rich
# Out:
#                     country  year        pop  income  lifeExp Continent
# 856    United Arab Emirates  1903    47200.0  3980.0     35.9      Asia
# 857    United Arab Emirates  1904    47500.0  4270.0     36.1      Asia
# 858    United Arab Emirates  1905    47700.0  4580.0     36.2      Asia
# 859    United Arab Emirates  1906    48000.0  4920.0     36.4      Asia
# 860    United Arab Emirates  1907    48200.0  5300.0     36.5      Asia
# ...                     ...   ...        ...     ...      ...       ...
# 45936          South Africa  1803  1460000.0  1700.0     33.5    Africa
# 45940          South Africa  1807  1490000.0  1730.0     33.5    Africa
# 45943          South Africa  1810  1500000.0  1630.0     33.5    Africa
# 45946          South Africa  1813  1520000.0  1650.0     33.5    Africa
# 45947          South Africa  1814  1530000.0  1670.0     33.5    Africa
#
# [4800 rows x 6 columns]

# %% [markdown]
# We observe that the number of rows is significantly smaller than the original dataframe. This is as expected, since we have filtered the 90th percentile countries. Let's print each group.

# %%
for name,group in gapminder_rich.groupby('year'):
    print()
    print("Year: " , name)
    print()
    print(group.country)
    print("-------------------")
# Out:
# Year:  1800
#
# 1004          Argentina
# 2008            Austria
# 2761            Belgium
# 6024             Brunei
# 7279        Switzerland
# 10542    Czech Republic
# 10793           Germany
# 11295           Denmark
# 12801             Spain
# 14056            France
# 14809    United Kingdom
# 16566            Greece
# 20331            Israel
# 20582             Italy
# 30873       Netherlands
# 38403          Suriname
# 43674           Uruguay
# 43925     United States
# 45933      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1801
#
# 1005          Argentina
# 2009            Austria
# 2762            Belgium
# 6025             Brunei
# 7280        Switzerland
# 10543    Czech Republic
# 10794           Germany
# 11296           Denmark
# 12802             Spain
# 14057            France
# 14810    United Kingdom
# 16567            Greece
# 20332            Israel
# 20583             Italy
# 30874       Netherlands
# 38404          Suriname
# 43675           Uruguay
# 43926     United States
# 45934      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1802
#
# 1006          Argentina
# 2010            Austria
# 2763            Belgium
# 6026             Brunei
# 7281        Switzerland
# 10544    Czech Republic
# 10795           Germany
# 11297           Denmark
# 12803             Spain
# 14058            France
# 14811    United Kingdom
# 16568            Greece
# 20333            Israel
# 20584             Italy
# 30875       Netherlands
# 38405          Suriname
# 43676           Uruguay
# 43927     United States
# 45935      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1803
#
# 1007          Argentina
# 2011            Austria
# 2764            Belgium
# 6027             Brunei
# 7282        Switzerland
# 10545    Czech Republic
# 10796           Germany
# 11298           Denmark
# 12804             Spain
# 14059            France
# 14812    United Kingdom
# 16569            Greece
# 20334            Israel
# 20585             Italy
# 30876       Netherlands
# 38406          Suriname
# 43677           Uruguay
# 43928     United States
# 45936      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1804
#
# 1008          Argentina
# 2012            Austria
# 2765            Belgium
# 6028             Brunei
# 7283        Switzerland
# 10546    Czech Republic
# 10797           Germany
# 11299           Denmark
# 12805             Spain
# 14060            France
# 14813    United Kingdom
# 16570            Greece
# 20335            Israel
# 20586             Italy
# 30877       Netherlands
# 33889          Portugal
# 38407          Suriname
# 43678           Uruguay
# 43929     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1805
#
# 1009          Argentina
# 2013            Austria
# 2766            Belgium
# 6029             Brunei
# 7284        Switzerland
# 10547    Czech Republic
# 10798           Germany
# 11300           Denmark
# 12806             Spain
# 14061            France
# 14814    United Kingdom
# 16571            Greece
# 20336            Israel
# 20587             Italy
# 30878       Netherlands
# 33890          Portugal
# 38408          Suriname
# 43679           Uruguay
# 43930     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1806
#
# 1010          Argentina
# 2014            Austria
# 2767            Belgium
# 6030             Brunei
# 7285        Switzerland
# 10548    Czech Republic
# 10799           Germany
# 11301           Denmark
# 12807             Spain
# 14062            France
# 14815    United Kingdom
# 16572            Greece
# 19333           Ireland
# 20337            Israel
# 20588             Italy
# 25357        Luxembourg
# 30879       Netherlands
# 38409          Suriname
# 43680           Uruguay
# 43931     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1807
#
# 1011          Argentina
# 2015            Austria
# 2768            Belgium
# 6031             Brunei
# 7286        Switzerland
# 10549    Czech Republic
# 10800           Germany
# 11302           Denmark
# 12808             Spain
# 14063            France
# 14816    United Kingdom
# 16573            Greece
# 20338            Israel
# 20589             Italy
# 30880       Netherlands
# 38410          Suriname
# 43681           Uruguay
# 43932     United States
# 45940      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1808
#
# 1012          Argentina
# 2016            Austria
# 2769            Belgium
# 6032             Brunei
# 7287        Switzerland
# 10550    Czech Republic
# 10801           Germany
# 11303           Denmark
# 12809             Spain
# 14064            France
# 14817    United Kingdom
# 16574            Greece
# 20339            Israel
# 20590             Italy
# 30881       Netherlands
# 33893          Portugal
# 38411          Suriname
# 43682           Uruguay
# 43933     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1809
#
# 1013          Argentina
# 2017            Austria
# 2770            Belgium
# 6033             Brunei
# 7288        Switzerland
# 10551    Czech Republic
# 10802           Germany
# 11304           Denmark
# 12810             Spain
# 14065            France
# 14818    United Kingdom
# 16575            Greece
# 19336           Ireland
# 20340            Israel
# 20591             Italy
# 25360        Luxembourg
# 30882       Netherlands
# 33894          Portugal
# 38412          Suriname
# 43683           Uruguay
# 43934     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1810
#
# 1014          Argentina
# 2018            Austria
# 2771            Belgium
# 6034             Brunei
# 7289        Switzerland
# 10552    Czech Republic
# 10803           Germany
# 11305           Denmark
# 12811             Spain
# 14066            France
# 14819    United Kingdom
# 16576            Greece
# 19337           Ireland
# 20341            Israel
# 20592             Italy
# 25361        Luxembourg
# 30883       Netherlands
# 38413          Suriname
# 43684           Uruguay
# 43935     United States
# 45943      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1811
#
# 1015          Argentina
# 2019            Austria
# 2772            Belgium
# 6035             Brunei
# 7290        Switzerland
# 10553    Czech Republic
# 10804           Germany
# 11306           Denmark
# 12812             Spain
# 14067            France
# 14820    United Kingdom
# 16577            Greece
# 19338           Ireland
# 20342            Israel
# 20593             Italy
# 25362        Luxembourg
# 30884       Netherlands
# 38414          Suriname
# 39167            Sweden
# 43685           Uruguay
# 43936     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1812
#
# 1016          Argentina
# 2020            Austria
# 2773            Belgium
# 6036             Brunei
# 7291        Switzerland
# 10554    Czech Republic
# 10805           Germany
# 11307           Denmark
# 12813             Spain
# 14068            France
# 14821    United Kingdom
# 16578            Greece
# 19339           Ireland
# 20343            Israel
# 20594             Italy
# 25363        Luxembourg
# 30885       Netherlands
# 38415          Suriname
# 43686           Uruguay
# 43937     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1813
#
# 1017          Argentina
# 2021            Austria
# 2774            Belgium
# 6037             Brunei
# 7292        Switzerland
# 10555    Czech Republic
# 10806           Germany
# 11308           Denmark
# 12814             Spain
# 14069            France
# 14822    United Kingdom
# 16579            Greece
# 20344            Israel
# 20595             Italy
# 30886       Netherlands
# 38416          Suriname
# 43687           Uruguay
# 43938     United States
# 45946      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1814
#
# 1018          Argentina
# 2022            Austria
# 2775            Belgium
# 6038             Brunei
# 7293        Switzerland
# 10556    Czech Republic
# 10807           Germany
# 11309           Denmark
# 12815             Spain
# 14070            France
# 14823    United Kingdom
# 16580            Greece
# 20345            Israel
# 20596             Italy
# 30887       Netherlands
# 38417          Suriname
# 43688           Uruguay
# 43939     United States
# 45947      South Africa
# Name: country, dtype: object
# -------------------
#
# Year:  1815
#
# 1019          Argentina
# 2023            Austria
# 2776            Belgium
# 6039             Brunei
# 7294        Switzerland
# 10557    Czech Republic
# 10808           Germany
# 11310           Denmark
# 12816             Spain
# 14071            France
# 14824    United Kingdom
# 16581            Greece
# 19342           Ireland
# 20346            Israel
# 20597             Italy
# 25366        Luxembourg
# 30888       Netherlands
# 35155            Russia
# 38418          Suriname
# 43689           Uruguay
# 43940     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1816
#
# 1020          Argentina
# 2024            Austria
# 2777            Belgium
# 6040             Brunei
# 7295        Switzerland
# 10558    Czech Republic
# 10809           Germany
# 11311           Denmark
# 12817             Spain
# 14072            France
# 14825    United Kingdom
# 16582            Greece
# 20347            Israel
# 20598             Italy
# 30889       Netherlands
# 38419          Suriname
# 39172            Sweden
# 43690           Uruguay
# 43941     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1817
#
# 1021          Argentina
# 2025            Austria
# 2778            Belgium
# 6041             Brunei
# 7045             Canada
# 7296        Switzerland
# 10559    Czech Republic
# 10810           Germany
# 11312           Denmark
# 12818             Spain
# 14073            France
# 14826    United Kingdom
# 16583            Greece
# 19344           Ireland
# 20348            Israel
# 20599             Italy
# 25368        Luxembourg
# 30890       Netherlands
# 35157            Russia
# 38420          Suriname
# 43691           Uruguay
# 43942     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1818
#
# 1022          Argentina
# 2026            Austria
# 2779            Belgium
# 6042             Brunei
# 7297        Switzerland
# 10560    Czech Republic
# 10811           Germany
# 11313           Denmark
# 12819             Spain
# 14074            France
# 14827    United Kingdom
# 16584            Greece
# 20349            Israel
# 20600             Italy
# 30891       Netherlands
# 33903          Portugal
# 38421          Suriname
# 43692           Uruguay
# 43943     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1819
#
# 1023          Argentina
# 2027            Austria
# 2780            Belgium
# 6043             Brunei
# 7298        Switzerland
# 10561    Czech Republic
# 10812           Germany
# 11314           Denmark
# 12820             Spain
# 14075            France
# 14828    United Kingdom
# 16585            Greece
# 20350            Israel
# 20601             Italy
# 30892       Netherlands
# 33904          Portugal
# 38422          Suriname
# 43693           Uruguay
# 43944     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1820
#
# 1024          Argentina
# 2028            Austria
# 2781            Belgium
# 6044             Brunei
# 7299        Switzerland
# 10562    Czech Republic
# 10813           Germany
# 11315           Denmark
# 12821             Spain
# 14076            France
# 14829    United Kingdom
# 16586            Greece
# 20351            Israel
# 20602             Italy
# 30893       Netherlands
# 33905          Portugal
# 38423          Suriname
# 43694           Uruguay
# 43945     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1821
#
# 1025          Argentina
# 2029            Austria
# 2782            Belgium
# 6045             Brunei
# 7300        Switzerland
# 10563    Czech Republic
# 10814           Germany
# 11316           Denmark
# 12822             Spain
# 14077            France
# 14830    United Kingdom
# 16587            Greece
# 20352            Israel
# 20603             Italy
# 30894       Netherlands
# 33906          Portugal
# 38424          Suriname
# 43695           Uruguay
# 43946     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1822
#
# 1026          Argentina
# 2030            Austria
# 2783            Belgium
# 6046             Brunei
# 7301        Switzerland
# 10564    Czech Republic
# 10815           Germany
# 11317           Denmark
# 12823             Spain
# 14078            France
# 14831    United Kingdom
# 16588            Greece
# 20353            Israel
# 20604             Italy
# 30895       Netherlands
# 33907          Portugal
# 38425          Suriname
# 43696           Uruguay
# 43947     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1823
#
# 1027          Argentina
# 2031            Austria
# 2784            Belgium
# 6047             Brunei
# 7051             Canada
# 7302        Switzerland
# 10565    Czech Republic
# 10816           Germany
# 11318           Denmark
# 12824             Spain
# 14079            France
# 14832    United Kingdom
# 16589            Greece
# 20354            Israel
# 20605             Italy
# 30896       Netherlands
# 33908          Portugal
# 38426          Suriname
# 43697           Uruguay
# 43948     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1824
#
# 1028          Argentina
# 2032            Austria
# 2785            Belgium
# 7052             Canada
# 7303        Switzerland
# 10566    Czech Republic
# 10817           Germany
# 11319           Denmark
# 12825             Spain
# 14080            France
# 14833    United Kingdom
# 16590            Greece
# 20355            Israel
# 20606             Italy
# 30897       Netherlands
# 33909          Portugal
# 38427          Suriname
# 43698           Uruguay
# 43949     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1825
#
# 1029          Argentina
# 2033            Austria
# 2786            Belgium
# 7053             Canada
# 7304        Switzerland
# 10567    Czech Republic
# 10818           Germany
# 11320           Denmark
# 12826             Spain
# 14081            France
# 14834    United Kingdom
# 16591            Greece
# 20356            Israel
# 20607             Italy
# 30898       Netherlands
# 38428          Suriname
# 39181            Sweden
# 43699           Uruguay
# 43950     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1826
#
# 1030          Argentina
# 2034            Austria
# 2787            Belgium
# 7054             Canada
# 7305        Switzerland
# 10568    Czech Republic
# 10819           Germany
# 11321           Denmark
# 12827             Spain
# 14082            France
# 14835    United Kingdom
# 16592            Greece
# 20357            Israel
# 20608             Italy
# 30899       Netherlands
# 33911          Portugal
# 38429          Suriname
# 39182            Sweden
# 43700           Uruguay
# 43951     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1827
#
# 1031          Argentina
# 2035            Austria
# 2788            Belgium
# 7055             Canada
# 7306        Switzerland
# 10569    Czech Republic
# 10820           Germany
# 11322           Denmark
# 12828             Spain
# 14083            France
# 14836    United Kingdom
# 19354           Ireland
# 20358            Israel
# 20609             Italy
# 30900       Netherlands
# 38430          Suriname
# 43701           Uruguay
# 43952     United States
# 44705         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1828
#
# 1032          Argentina
# 2036            Austria
# 2789            Belgium
# 7056             Canada
# 7307        Switzerland
# 10570    Czech Republic
# 10821           Germany
# 11323           Denmark
# 12829             Spain
# 14084            France
# 14837    United Kingdom
# 19355           Ireland
# 20359            Israel
# 20610             Italy
# 30901       Netherlands
# 38431          Suriname
# 43702           Uruguay
# 43953     United States
# 44706         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1829
#
# 1033          Argentina
# 2037            Austria
# 2790            Belgium
# 7308        Switzerland
# 10571    Czech Republic
# 10822           Germany
# 11324           Denmark
# 12830             Spain
# 14085            France
# 14838    United Kingdom
# 19356           Ireland
# 20360            Israel
# 20611             Italy
# 30902       Netherlands
# 33914          Portugal
# 38432          Suriname
# 43703           Uruguay
# 43954     United States
# 44707         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1830
#
# 1034          Argentina
# 2038            Austria
# 2791            Belgium
# 7309        Switzerland
# 10572    Czech Republic
# 10823           Germany
# 11325           Denmark
# 12831             Spain
# 14086            France
# 14839    United Kingdom
# 19357           Ireland
# 20361            Israel
# 20612             Italy
# 30903       Netherlands
# 33915          Portugal
# 38433          Suriname
# 43704           Uruguay
# 43955     United States
# 44708         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1831
#
# 1035          Argentina
# 2039            Austria
# 2792            Belgium
# 7059             Canada
# 7310        Switzerland
# 10573    Czech Republic
# 10824           Germany
# 11326           Denmark
# 12832             Spain
# 14087            France
# 14840    United Kingdom
# 19358           Ireland
# 20362            Israel
# 20613             Italy
# 25382        Luxembourg
# 30904       Netherlands
# 38434          Suriname
# 43705           Uruguay
# 43956     United States
# 44709         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1832
#
# 1036          Argentina
# 2040            Austria
# 2793            Belgium
# 7060             Canada
# 7311        Switzerland
# 10574    Czech Republic
# 10825           Germany
# 11327           Denmark
# 12833             Spain
# 14088            France
# 14841    United Kingdom
# 19359           Ireland
# 20363            Israel
# 20614             Italy
# 30905       Netherlands
# 38435          Suriname
# 43706           Uruguay
# 43957     United States
# 44710         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1833
#
# 1037          Argentina
# 2041            Austria
# 2794            Belgium
# 7061             Canada
# 7312        Switzerland
# 10575    Czech Republic
# 10826           Germany
# 11328           Denmark
# 12834             Spain
# 14089            France
# 14842    United Kingdom
# 19360           Ireland
# 20364            Israel
# 20615             Italy
# 30906       Netherlands
# 38436          Suriname
# 43707           Uruguay
# 43958     United States
# 44711         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1834
#
# 1038          Argentina
# 2042            Austria
# 2795            Belgium
# 7062             Canada
# 7313        Switzerland
# 10576    Czech Republic
# 10827           Germany
# 11329           Denmark
# 12835             Spain
# 14090            France
# 14843    United Kingdom
# 19361           Ireland
# 20365            Israel
# 20616             Italy
# 30907       Netherlands
# 38437          Suriname
# 43708           Uruguay
# 43959     United States
# 44712         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1835
#
# 1039          Argentina
# 1792          Australia
# 2043            Austria
# 2796            Belgium
# 7314        Switzerland
# 10577    Czech Republic
# 10828           Germany
# 11330           Denmark
# 14091            France
# 14844    United Kingdom
# 16601            Greece
# 19362           Ireland
# 20366            Israel
# 20617             Italy
# 30908       Netherlands
# 38438          Suriname
# 43709           Uruguay
# 43960     United States
# 44713         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1836
#
# 1040          Argentina
# 1793          Australia
# 2044            Austria
# 2797            Belgium
# 7315        Switzerland
# 10578    Czech Republic
# 10829           Germany
# 11331           Denmark
# 14092            France
# 14845    United Kingdom
# 16602            Greece
# 19363           Ireland
# 20367            Israel
# 20618             Italy
# 30909       Netherlands
# 38439          Suriname
# 43710           Uruguay
# 43961     United States
# 44714         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1837
#
# 1041          Argentina
# 1794          Australia
# 2045            Austria
# 2798            Belgium
# 7065             Canada
# 7316        Switzerland
# 10579    Czech Republic
# 10830           Germany
# 11332           Denmark
# 14093            France
# 14846    United Kingdom
# 16603            Greece
# 19364           Ireland
# 20368            Israel
# 20619             Italy
# 30910       Netherlands
# 38440          Suriname
# 43711           Uruguay
# 43962     United States
# 44715         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1838
#
# 1042          Argentina
# 1795          Australia
# 2046            Austria
# 2799            Belgium
# 7066             Canada
# 7317        Switzerland
# 10580    Czech Republic
# 10831           Germany
# 11333           Denmark
# 14094            France
# 14847    United Kingdom
# 16604            Greece
# 19365           Ireland
# 20369            Israel
# 20620             Italy
# 30911       Netherlands
# 38441          Suriname
# 43712           Uruguay
# 43963     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1839
#
# 1043          Argentina
# 2047            Austria
# 2800            Belgium
# 7067             Canada
# 7318        Switzerland
# 10581    Czech Republic
# 10832           Germany
# 11334           Denmark
# 14095            France
# 14848    United Kingdom
# 16605            Greece
# 19366           Ireland
# 20370            Israel
# 20621             Italy
# 25390        Luxembourg
# 30912       Netherlands
# 38442          Suriname
# 43713           Uruguay
# 43964     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1840
#
# 1044          Argentina
# 1797          Australia
# 2048            Austria
# 2801            Belgium
# 7068             Canada
# 7319        Switzerland
# 10582    Czech Republic
# 10833           Germany
# 11335           Denmark
# 14096            France
# 14849    United Kingdom
# 16606            Greece
# 19367           Ireland
# 20371            Israel
# 20622             Italy
# 30913       Netherlands
# 38443          Suriname
# 43714           Uruguay
# 43965     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1841
#
# 1045          Argentina
# 1798          Australia
# 2049            Austria
# 2802            Belgium
# 7069             Canada
# 7320        Switzerland
# 10583    Czech Republic
# 10834           Germany
# 11336           Denmark
# 14097            France
# 14850    United Kingdom
# 16607            Greece
# 19368           Ireland
# 20372            Israel
# 20623             Italy
# 30914       Netherlands
# 38444          Suriname
# 43715           Uruguay
# 43966     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1842
#
# 1046          Argentina
# 2050            Austria
# 2803            Belgium
# 7070             Canada
# 7321        Switzerland
# 10584    Czech Republic
# 10835           Germany
# 11337           Denmark
# 14098            France
# 14851    United Kingdom
# 16608            Greece
# 19369           Ireland
# 20373            Israel
# 20624             Italy
# 30915       Netherlands
# 38445          Suriname
# 43716           Uruguay
# 43967     United States
# 44720         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1843
#
# 1047          Argentina
# 1800          Australia
# 2051            Austria
# 2804            Belgium
# 7071             Canada
# 7322        Switzerland
# 10585    Czech Republic
# 10836           Germany
# 11338           Denmark
# 14099            France
# 14852    United Kingdom
# 19370           Ireland
# 20374            Israel
# 20625             Italy
# 25394        Luxembourg
# 30916       Netherlands
# 38446          Suriname
# 43717           Uruguay
# 43968     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1844
#
# 1048          Argentina
# 1801          Australia
# 2052            Austria
# 2805            Belgium
# 7072             Canada
# 7323        Switzerland
# 10586    Czech Republic
# 10837           Germany
# 11339           Denmark
# 14100            France
# 14853    United Kingdom
# 19371           Ireland
# 20375            Israel
# 20626             Italy
# 25395        Luxembourg
# 30917       Netherlands
# 38447          Suriname
# 43718           Uruguay
# 43969     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1845
#
# 1049          Argentina
# 1802          Australia
# 2053            Austria
# 2806            Belgium
# 7073             Canada
# 7324        Switzerland
# 10587    Czech Republic
# 10838           Germany
# 11340           Denmark
# 14101            France
# 14854    United Kingdom
# 20376            Israel
# 20627             Italy
# 25396        Luxembourg
# 30918       Netherlands
# 38448          Suriname
# 43719           Uruguay
# 43970     United States
# 44723         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1846
#
# 1050          Argentina
# 1803          Australia
# 2054            Austria
# 2807            Belgium
# 7074             Canada
# 7325        Switzerland
# 10588    Czech Republic
# 10839           Germany
# 11341           Denmark
# 14102            France
# 14855    United Kingdom
# 20377            Israel
# 20628             Italy
# 25397        Luxembourg
# 30919       Netherlands
# 38449          Suriname
# 43720           Uruguay
# 43971     United States
# 44724         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1847
#
# 1051           Argentina
# 1804           Australia
# 2055             Austria
# 2808             Belgium
# 7075              Canada
# 7326         Switzerland
# 10589     Czech Republic
# 10840            Germany
# 11342            Denmark
# 14103             France
# 14856     United Kingdom
# 20378             Israel
# 20629              Italy
# 25398         Luxembourg
# 30920        Netherlands
# 38450           Suriname
# 38701    Slovak Republic
# 43721            Uruguay
# 43972      United States
# Name: country, dtype: object
# -------------------
#
# Year:  1848
#
# 1052           Argentina
# 1805           Australia
# 2056             Austria
# 2809             Belgium
# 7076              Canada
# 7327         Switzerland
# 10590     Czech Republic
# 10841            Germany
# 11343            Denmark
# 14104             France
# 14857     United Kingdom
# 20379             Israel
# 20630              Italy
# 25399         Luxembourg
# 30921        Netherlands
# 38451           Suriname
# 38702    Slovak Republic
# 43722            Uruguay
# 43973      United States
# Name: country, dtype: object
# -------------------
#
# Year:  1849
#
# 1053          Argentina
# 1806          Australia
# 2057            Austria
# 2810            Belgium
# 7077             Canada
# 7328        Switzerland
# 10591    Czech Republic
# 10842           Germany
# 11344           Denmark
# 14105            France
# 14858    United Kingdom
# 20380            Israel
# 20631             Italy
# 25400        Luxembourg
# 30922       Netherlands
# 31675       New Zealand
# 38452          Suriname
# 43723           Uruguay
# 43974     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1850
#
# 1054          Argentina
# 1807          Australia
# 2058            Austria
# 2811            Belgium
# 7078             Canada
# 7329        Switzerland
# 10592    Czech Republic
# 10843           Germany
# 11345           Denmark
# 14106            France
# 14859    United Kingdom
# 20381            Israel
# 20632             Italy
# 25401        Luxembourg
# 30923       Netherlands
# 38453          Suriname
# 43724           Uruguay
# 43975     United States
# 44728         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1851
#
# 1055          Argentina
# 1808          Australia
# 2059            Austria
# 2812            Belgium
# 7079             Canada
# 7330        Switzerland
# 10593    Czech Republic
# 10844           Germany
# 11346           Denmark
# 14107            France
# 14860    United Kingdom
# 16617            Greece
# 19378           Ireland
# 20382            Israel
# 20633             Italy
# 25402        Luxembourg
# 30924       Netherlands
# 43725           Uruguay
# 43976     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1852
#
# 1056          Argentina
# 1809          Australia
# 2060            Austria
# 2813            Belgium
# 7080             Canada
# 7331        Switzerland
# 10594    Czech Republic
# 10845           Germany
# 11347           Denmark
# 14108            France
# 14861    United Kingdom
# 19379           Ireland
# 20383            Israel
# 20634             Italy
# 25403        Luxembourg
# 30925       Netherlands
# 31678       New Zealand
# 43726           Uruguay
# 43977     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1853
#
# 1057          Argentina
# 1810          Australia
# 2061            Austria
# 2814            Belgium
# 7081             Canada
# 7332        Switzerland
# 10595    Czech Republic
# 10846           Germany
# 11348           Denmark
# 14109            France
# 14862    United Kingdom
# 19380           Ireland
# 20384            Israel
# 20635             Italy
# 25404        Luxembourg
# 30926       Netherlands
# 31679       New Zealand
# 43727           Uruguay
# 43978     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1854
#
# 1058          Argentina
# 1811          Australia
# 2062            Austria
# 2815            Belgium
# 7082             Canada
# 7333        Switzerland
# 10596    Czech Republic
# 10847           Germany
# 11349           Denmark
# 14110            France
# 14863    United Kingdom
# 19381           Ireland
# 20385            Israel
# 20636             Italy
# 25405        Luxembourg
# 30927       Netherlands
# 31680       New Zealand
# 43728           Uruguay
# 43979     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1855
#
# 1812          Australia
# 2063            Austria
# 2816            Belgium
# 7083             Canada
# 7334        Switzerland
# 10597    Czech Republic
# 10848           Germany
# 11350           Denmark
# 14111            France
# 14864    United Kingdom
# 19382           Ireland
# 20386            Israel
# 20637             Italy
# 25406        Luxembourg
# 30928       Netherlands
# 31681       New Zealand
# 43729           Uruguay
# 43980     United States
# 44733         Venezuela
# Name: country, dtype: object
# -------------------
#
# Year:  1856
#
# 1060          Argentina
# 1813          Australia
# 2064            Austria
# 2817            Belgium
# 7084             Canada
# 7335        Switzerland
# 10598    Czech Republic
# 10849           Germany
# 11351           Denmark
# 14112            France
# 14865    United Kingdom
# 19383           Ireland
# 20387            Israel
# 20638             Italy
# 25407        Luxembourg
# 30929       Netherlands
# 31682       New Zealand
# 43730           Uruguay
# 43981     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1857
#
# 1814          Australia
# 2065            Austria
# 2818            Belgium
# 7085             Canada
# 7336        Switzerland
# 10599    Czech Republic
# 10850           Germany
# 11352           Denmark
# 14113            France
# 14866    United Kingdom
# 16623            Greece
# 19384           Ireland
# 20388            Israel
# 20639             Italy
# 25408        Luxembourg
# 30930       Netherlands
# 31683       New Zealand
# 43731           Uruguay
# 43982     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1858
#
# 1815          Australia
# 2066            Austria
# 2819            Belgium
# 7086             Canada
# 7337        Switzerland
# 10600    Czech Republic
# 10851           Germany
# 11353           Denmark
# 14114            France
# 14867    United Kingdom
# 16624            Greece
# 19385           Ireland
# 20389            Israel
# 20640             Italy
# 25409        Luxembourg
# 30931       Netherlands
# 31684       New Zealand
# 43732           Uruguay
# 43983     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1859
#
# 1816          Australia
# 2067            Austria
# 2820            Belgium
# 7087             Canada
# 7338        Switzerland
# 10601    Czech Republic
# 10852           Germany
# 11354           Denmark
# 14115            France
# 14868    United Kingdom
# 16625            Greece
# 19386           Ireland
# 20390            Israel
# 20641             Italy
# 25410        Luxembourg
# 30932       Netherlands
# 31685       New Zealand
# 43733           Uruguay
# 43984     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1860
#
# 1064          Argentina
# 1817          Australia
# 2068            Austria
# 2821            Belgium
# 7088             Canada
# 7339        Switzerland
# 10602    Czech Republic
# 10853           Germany
# 11355           Denmark
# 14116            France
# 14869    United Kingdom
# 19387           Ireland
# 20391            Israel
# 20642             Italy
# 25411        Luxembourg
# 30933       Netherlands
# 31686       New Zealand
# 43734           Uruguay
# 43985     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1861
#
# 1818          Australia
# 2069            Austria
# 2822            Belgium
# 7089             Canada
# 7340        Switzerland
# 10603    Czech Republic
# 10854           Germany
# 11356           Denmark
# 14117            France
# 14870    United Kingdom
# 16627            Greece
# 19388           Ireland
# 20392            Israel
# 20643             Italy
# 25412        Luxembourg
# 30934       Netherlands
# 31687       New Zealand
# 43735           Uruguay
# 43986     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1862
#
# 1819          Australia
# 2070            Austria
# 2823            Belgium
# 7090             Canada
# 7341        Switzerland
# 10604    Czech Republic
# 10855           Germany
# 11357           Denmark
# 14118            France
# 14871    United Kingdom
# 16628            Greece
# 19389           Ireland
# 20393            Israel
# 20644             Italy
# 25413        Luxembourg
# 30935       Netherlands
# 31688       New Zealand
# 43736           Uruguay
# 43987     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1863
#
# 1067          Argentina
# 1820          Australia
# 2071            Austria
# 2824            Belgium
# 7091             Canada
# 7342        Switzerland
# 10605    Czech Republic
# 10856           Germany
# 11358           Denmark
# 14119            France
# 14872    United Kingdom
# 19390           Ireland
# 20394            Israel
# 20645             Italy
# 25414        Luxembourg
# 30936       Netherlands
# 31689       New Zealand
# 43737           Uruguay
# 43988     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1864
#
# 1068          Argentina
# 1821          Australia
# 2072            Austria
# 2825            Belgium
# 7092             Canada
# 7343        Switzerland
# 10606    Czech Republic
# 10857           Germany
# 11359           Denmark
# 14120            France
# 14873    United Kingdom
# 19391           Ireland
# 20395            Israel
# 20646             Italy
# 25415        Luxembourg
# 30937       Netherlands
# 31690       New Zealand
# 43738           Uruguay
# 43989     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1865
#
# 1069          Argentina
# 1822          Australia
# 2073            Austria
# 2826            Belgium
# 7093             Canada
# 7344        Switzerland
# 10607    Czech Republic
# 10858           Germany
# 11360           Denmark
# 14121            France
# 14874    United Kingdom
# 19392           Ireland
# 20396            Israel
# 20647             Italy
# 25416        Luxembourg
# 30938       Netherlands
# 31691       New Zealand
# 43739           Uruguay
# 43990     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1866
#
# 1070          Argentina
# 1823          Australia
# 2074            Austria
# 2827            Belgium
# 7094             Canada
# 7345        Switzerland
# 10608    Czech Republic
# 10859           Germany
# 11361           Denmark
# 14122            France
# 14875    United Kingdom
# 19393           Ireland
# 20397            Israel
# 20648             Italy
# 25417        Luxembourg
# 30939       Netherlands
# 31692       New Zealand
# 43740           Uruguay
# 43991     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1867
#
# 1071          Argentina
# 1824          Australia
# 2075            Austria
# 2828            Belgium
# 7095             Canada
# 7346        Switzerland
# 10609    Czech Republic
# 10860           Germany
# 11362           Denmark
# 14123            France
# 14876    United Kingdom
# 19394           Ireland
# 20398            Israel
# 20649             Italy
# 25418        Luxembourg
# 30940       Netherlands
# 31693       New Zealand
# 43741           Uruguay
# 43992     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1868
#
# 1072          Argentina
# 1825          Australia
# 2076            Austria
# 2829            Belgium
# 7096             Canada
# 7347        Switzerland
# 10610    Czech Republic
# 10861           Germany
# 11363           Denmark
# 14124            France
# 14877    United Kingdom
# 19395           Ireland
# 20399            Israel
# 20650             Italy
# 25419        Luxembourg
# 30941       Netherlands
# 31694       New Zealand
# 43742           Uruguay
# 43993     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1869
#
# 1073          Argentina
# 1826          Australia
# 2077            Austria
# 2830            Belgium
# 7097             Canada
# 7348        Switzerland
# 10611    Czech Republic
# 10862           Germany
# 11364           Denmark
# 14125            France
# 14878    United Kingdom
# 19396           Ireland
# 20400            Israel
# 20651             Italy
# 25420        Luxembourg
# 30942       Netherlands
# 31695       New Zealand
# 43743           Uruguay
# 43994     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1870
#
# 1074          Argentina
# 1827          Australia
# 2078            Austria
# 2831            Belgium
# 7098             Canada
# 7349        Switzerland
# 10612    Czech Republic
# 10863           Germany
# 11365           Denmark
# 14126            France
# 14879    United Kingdom
# 19397           Ireland
# 20401            Israel
# 20652             Italy
# 25421        Luxembourg
# 30943       Netherlands
# 31696       New Zealand
# 43744           Uruguay
# 43995     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1871
#
# 1075          Argentina
# 1828          Australia
# 2079            Austria
# 2832            Belgium
# 7099             Canada
# 7350        Switzerland
# 10613    Czech Republic
# 10864           Germany
# 11366           Denmark
# 14127            France
# 14880    United Kingdom
# 19398           Ireland
# 20402            Israel
# 20653             Italy
# 25422        Luxembourg
# 30944       Netherlands
# 31697       New Zealand
# 43745           Uruguay
# 43996     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1872
#
# 1076          Argentina
# 1829          Australia
# 2080            Austria
# 2833            Belgium
# 7100             Canada
# 7351        Switzerland
# 10614    Czech Republic
# 10865           Germany
# 11367           Denmark
# 14128            France
# 14881    United Kingdom
# 19399           Ireland
# 20403            Israel
# 20654             Italy
# 25423        Luxembourg
# 30945       Netherlands
# 31698       New Zealand
# 43746           Uruguay
# 43997     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1873
#
# 1077          Argentina
# 1830          Australia
# 2081            Austria
# 2834            Belgium
# 7101             Canada
# 7352        Switzerland
# 10615    Czech Republic
# 10866           Germany
# 11368           Denmark
# 14129            France
# 14882    United Kingdom
# 19400           Ireland
# 20404            Israel
# 20655             Italy
# 25424        Luxembourg
# 30946       Netherlands
# 31699       New Zealand
# 43747           Uruguay
# 43998     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1874
#
# 1078          Argentina
# 1831          Australia
# 2082            Austria
# 2835            Belgium
# 7102             Canada
# 7353        Switzerland
# 10616    Czech Republic
# 10867           Germany
# 11369           Denmark
# 14130            France
# 14883    United Kingdom
# 19401           Ireland
# 20405            Israel
# 20656             Italy
# 25425        Luxembourg
# 30947       Netherlands
# 31700       New Zealand
# 43748           Uruguay
# 43999     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1875
#
# 1079          Argentina
# 1832          Australia
# 2083            Austria
# 2836            Belgium
# 7103             Canada
# 7354        Switzerland
# 10617    Czech Republic
# 10868           Germany
# 11370           Denmark
# 14131            France
# 14884    United Kingdom
# 19402           Ireland
# 20406            Israel
# 20657             Italy
# 25426        Luxembourg
# 30948       Netherlands
# 31701       New Zealand
# 43749           Uruguay
# 44000     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1876
#
# 1080          Argentina
# 1833          Australia
# 2084            Austria
# 2837            Belgium
# 7104             Canada
# 7355        Switzerland
# 10618    Czech Republic
# 10869           Germany
# 11371           Denmark
# 14132            France
# 14885    United Kingdom
# 19403           Ireland
# 20407            Israel
# 20658             Italy
# 25427        Luxembourg
# 30949       Netherlands
# 31702       New Zealand
# 43750           Uruguay
# 44001     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1877
#
# 1081          Argentina
# 1834          Australia
# 2085            Austria
# 2838            Belgium
# 7105             Canada
# 7356        Switzerland
# 10619    Czech Republic
# 10870           Germany
# 11372           Denmark
# 12878             Spain
# 14133            France
# 14886    United Kingdom
# 19404           Ireland
# 20659             Italy
# 25428        Luxembourg
# 30950       Netherlands
# 31703       New Zealand
# 43751           Uruguay
# 44002     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1878
#
# 1082          Argentina
# 1835          Australia
# 2086            Austria
# 2839            Belgium
# 7106             Canada
# 7357        Switzerland
# 10620    Czech Republic
# 10871           Germany
# 11373           Denmark
# 14134            France
# 14887    United Kingdom
# 19405           Ireland
# 20409            Israel
# 20660             Italy
# 25429        Luxembourg
# 30951       Netherlands
# 31704       New Zealand
# 43752           Uruguay
# 44003     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1879
#
# 1083          Argentina
# 1836          Australia
# 2087            Austria
# 2840            Belgium
# 7107             Canada
# 7358        Switzerland
# 10621    Czech Republic
# 10872           Germany
# 11374           Denmark
# 14135            France
# 14888    United Kingdom
# 19406           Ireland
# 20410            Israel
# 20661             Italy
# 25430        Luxembourg
# 30952       Netherlands
# 31705       New Zealand
# 43753           Uruguay
# 44004     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1880
#
# 1084          Argentina
# 1837          Australia
# 2088            Austria
# 2841            Belgium
# 7108             Canada
# 7359        Switzerland
# 10622    Czech Republic
# 10873           Germany
# 11375           Denmark
# 14136            France
# 14889    United Kingdom
# 19407           Ireland
# 20411            Israel
# 20662             Italy
# 25431        Luxembourg
# 30953       Netherlands
# 31706       New Zealand
# 43754           Uruguay
# 44005     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1881
#
# 1085          Argentina
# 1838          Australia
# 2089            Austria
# 2842            Belgium
# 7109             Canada
# 7360        Switzerland
# 10623    Czech Republic
# 10874           Germany
# 11376           Denmark
# 12882             Spain
# 14137            France
# 14890    United Kingdom
# 19408           Ireland
# 20412            Israel
# 20663             Italy
# 25432        Luxembourg
# 30954       Netherlands
# 31707       New Zealand
# 43755           Uruguay
# 44006     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1882
#
# 1086          Argentina
# 1839          Australia
# 2090            Austria
# 2843            Belgium
# 7110             Canada
# 7361        Switzerland
# 7612              Chile
# 10624    Czech Republic
# 10875           Germany
# 11377           Denmark
# 14138            France
# 14891    United Kingdom
# 19409           Ireland
# 20664             Italy
# 25433        Luxembourg
# 30955       Netherlands
# 31708       New Zealand
# 43756           Uruguay
# 44007     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1883
#
# 1087          Argentina
# 1840          Australia
# 2091            Austria
# 2844            Belgium
# 7111             Canada
# 7362        Switzerland
# 7613              Chile
# 10625    Czech Republic
# 10876           Germany
# 11378           Denmark
# 14139            France
# 14892    United Kingdom
# 19410           Ireland
# 20665             Italy
# 25434        Luxembourg
# 30956       Netherlands
# 31709       New Zealand
# 43757           Uruguay
# 44008     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1884
#
# 1088          Argentina
# 1841          Australia
# 2092            Austria
# 2845            Belgium
# 7112             Canada
# 7363        Switzerland
# 7614              Chile
# 10626    Czech Republic
# 10877           Germany
# 11379           Denmark
# 14140            France
# 14893    United Kingdom
# 19411           Ireland
# 20666             Italy
# 25435        Luxembourg
# 30957       Netherlands
# 31710       New Zealand
# 43758           Uruguay
# 44009     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1885
#
# 1089          Argentina
# 1842          Australia
# 2093            Austria
# 2846            Belgium
# 7113             Canada
# 7364        Switzerland
# 10627    Czech Republic
# 10878           Germany
# 11380           Denmark
# 14141            France
# 14894    United Kingdom
# 19412           Ireland
# 20416            Israel
# 20667             Italy
# 25436        Luxembourg
# 30958       Netherlands
# 31711       New Zealand
# 43759           Uruguay
# 44010     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1886
#
# 1090          Argentina
# 1843          Australia
# 2094            Austria
# 2847            Belgium
# 7114             Canada
# 7365        Switzerland
# 7616              Chile
# 10628    Czech Republic
# 10879           Germany
# 11381           Denmark
# 14142            France
# 14895    United Kingdom
# 19413           Ireland
# 20668             Italy
# 25437        Luxembourg
# 30959       Netherlands
# 31712       New Zealand
# 43760           Uruguay
# 44011     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1887
#
# 1091          Argentina
# 1844          Australia
# 2095            Austria
# 2848            Belgium
# 7115             Canada
# 7366        Switzerland
# 7617              Chile
# 10629    Czech Republic
# 10880           Germany
# 11382           Denmark
# 14143            France
# 14896    United Kingdom
# 19414           Ireland
# 20669             Italy
# 25438        Luxembourg
# 30960       Netherlands
# 31713       New Zealand
# 43761           Uruguay
# 44012     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1888
#
# 1092          Argentina
# 1845          Australia
# 2096            Austria
# 2849            Belgium
# 7116             Canada
# 7367        Switzerland
# 10630    Czech Republic
# 10881           Germany
# 11383           Denmark
# 14144            France
# 14897    United Kingdom
# 19415           Ireland
# 20670             Italy
# 25439        Luxembourg
# 30961       Netherlands
# 31212            Norway
# 31714       New Zealand
# 43762           Uruguay
# 44013     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1889
#
# 1093          Argentina
# 1846          Australia
# 2097            Austria
# 2850            Belgium
# 7117             Canada
# 7368        Switzerland
# 10631    Czech Republic
# 10882           Germany
# 11384           Denmark
# 14145            France
# 14898    United Kingdom
# 19416           Ireland
# 20671             Italy
# 25440        Luxembourg
# 30962       Netherlands
# 31213            Norway
# 31715       New Zealand
# 43763           Uruguay
# 44014     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1890
#
# 1094          Argentina
# 1847          Australia
# 2098            Austria
# 2851            Belgium
# 7118             Canada
# 7369        Switzerland
# 7620              Chile
# 10632    Czech Republic
# 10883           Germany
# 11385           Denmark
# 14146            France
# 14899    United Kingdom
# 19417           Ireland
# 20672             Italy
# 25441        Luxembourg
# 30963       Netherlands
# 31716       New Zealand
# 43764           Uruguay
# 44015     United States
# Name: country, dtype: object
# -------------------
#
# Year:  1891
#
# 1095          Argentina
# 1848          Australia
# 2099            Austria
# 2852            Belgium
# 7119             Canada
# 7370        Switzerland
# 7621              Chile
# 10633    Czech Republic
# 10884           Germany
# 11386           Denmark
# 14147            France
# 14900    United Kingdom
# ...
# 36620               Singapore
# 39381                  Sweden
# 42895                  Taiwan
# 44150           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2026
#
# 979      United Arab Emirates
# 1983                Australia
# 2234                  Austria
# 2987                  Belgium
# 6250                   Brunei
# 7505              Switzerland
# 11019                 Germany
# 11521                 Denmark
# 17796        Hong Kong, China
# 19553                 Ireland
# 20306                 Iceland
# 25577              Luxembourg
# 31099             Netherlands
# 31350                  Norway
# 34864                   Qatar
# 36621               Singapore
# 39382                  Sweden
# 42896                  Taiwan
# 44151           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2027
#
# 980      United Arab Emirates
# 1984                Australia
# 2235                  Austria
# 2988                  Belgium
# 6251                   Brunei
# 7506              Switzerland
# 11020                 Germany
# 11522                 Denmark
# 17797        Hong Kong, China
# 19554                 Ireland
# 20307                 Iceland
# 25578              Luxembourg
# 31100             Netherlands
# 31351                  Norway
# 34865                   Qatar
# 36622               Singapore
# 39383                  Sweden
# 42897                  Taiwan
# 44152           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2028
#
# 981      United Arab Emirates
# 1985                Australia
# 2236                  Austria
# 2989                  Belgium
# 6252                   Brunei
# 7507              Switzerland
# 11021                 Germany
# 11523                 Denmark
# 17798        Hong Kong, China
# 19555                 Ireland
# 20308                 Iceland
# 25579              Luxembourg
# 31101             Netherlands
# 31352                  Norway
# 34866                   Qatar
# 36623               Singapore
# 39384                  Sweden
# 42898                  Taiwan
# 44153           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2029
#
# 982      United Arab Emirates
# 1986                Australia
# 2237                  Austria
# 2990                  Belgium
# 6253                   Brunei
# 7508              Switzerland
# 11022                 Germany
# 11524                 Denmark
# 17799        Hong Kong, China
# 19556                 Ireland
# 20309                 Iceland
# 25580              Luxembourg
# 31102             Netherlands
# 31353                  Norway
# 34867                   Qatar
# 36624               Singapore
# 39385                  Sweden
# 42899                  Taiwan
# 44154           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2030
#
# 983      United Arab Emirates
# 1987                Australia
# 2238                  Austria
# 2991                  Belgium
# 6254                   Brunei
# 7509              Switzerland
# 11023                 Germany
# 11525                 Denmark
# 17800        Hong Kong, China
# 19557                 Ireland
# 20310                 Iceland
# 25581              Luxembourg
# 31103             Netherlands
# 31354                  Norway
# 34868                   Qatar
# 36625               Singapore
# 39386                  Sweden
# 42900                  Taiwan
# 44155           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2031
#
# 984      United Arab Emirates
# 2239                  Austria
# 2992                  Belgium
# 6255                   Brunei
# 7510              Switzerland
# 11024                 Germany
# 11526                 Denmark
# 17801        Hong Kong, China
# 19558                 Ireland
# 20311                 Iceland
# 25582              Luxembourg
# 27841                   Malta
# 31104             Netherlands
# 31355                  Norway
# 34869                   Qatar
# 36626               Singapore
# 39387                  Sweden
# 42901                  Taiwan
# 44156           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2032
#
# 985      United Arab Emirates
# 2240                  Austria
# 2993                  Belgium
# 6256                   Brunei
# 7511              Switzerland
# 11025                 Germany
# 11527                 Denmark
# 17802        Hong Kong, China
# 19559                 Ireland
# 20312                 Iceland
# 25583              Luxembourg
# 27842                   Malta
# 31105             Netherlands
# 31356                  Norway
# 34870                   Qatar
# 36627               Singapore
# 39388                  Sweden
# 42902                  Taiwan
# 44157           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2033
#
# 986      United Arab Emirates
# 2241                  Austria
# 2994                  Belgium
# 6257                   Brunei
# 7512              Switzerland
# 11026                 Germany
# 11528                 Denmark
# 17803        Hong Kong, China
# 19560                 Ireland
# 20313                 Iceland
# 25584              Luxembourg
# 27843                   Malta
# 31106             Netherlands
# 31357                  Norway
# 34871                   Qatar
# 36628               Singapore
# 39389                  Sweden
# 42903                  Taiwan
# 44158           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2034
#
# 987      United Arab Emirates
# 2242                  Austria
# 2995                  Belgium
# 6258                   Brunei
# 7513              Switzerland
# 11027                 Germany
# 11529                 Denmark
# 17804        Hong Kong, China
# 19561                 Ireland
# 20314                 Iceland
# 25585              Luxembourg
# 27844                   Malta
# 31107             Netherlands
# 31358                  Norway
# 34872                   Qatar
# 36629               Singapore
# 39390                  Sweden
# 42904                  Taiwan
# 44159           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2035
#
# 988      United Arab Emirates
# 2243                  Austria
# 2996                  Belgium
# 6259                   Brunei
# 7514              Switzerland
# 11028                 Germany
# 11530                 Denmark
# 17805        Hong Kong, China
# 19562                 Ireland
# 20315                 Iceland
# 25586              Luxembourg
# 27845                   Malta
# 31108             Netherlands
# 31359                  Norway
# 34873                   Qatar
# 36630               Singapore
# 39391                  Sweden
# 42905                  Taiwan
# 44160           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2036
#
# 989      United Arab Emirates
# 2244                  Austria
# 2997                  Belgium
# 6260                   Brunei
# 7515              Switzerland
# 11029                 Germany
# 11531                 Denmark
# 17806        Hong Kong, China
# 19563                 Ireland
# 20316                 Iceland
# 25587              Luxembourg
# 27846                   Malta
# 31109             Netherlands
# 31360                  Norway
# 34874                   Qatar
# 36631               Singapore
# 39392                  Sweden
# 42906                  Taiwan
# 44161           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2037
#
# 990      United Arab Emirates
# 2245                  Austria
# 2998                  Belgium
# 6261                   Brunei
# 7516              Switzerland
# 11030                 Germany
# 11532                 Denmark
# 17807        Hong Kong, China
# 19564                 Ireland
# 20317                 Iceland
# 25588              Luxembourg
# 27847                   Malta
# 31110             Netherlands
# 31361                  Norway
# 34875                   Qatar
# 36632               Singapore
# 39393                  Sweden
# 42907                  Taiwan
# 44162           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2038
#
# 991      United Arab Emirates
# 2246                  Austria
# 2999                  Belgium
# 6262                   Brunei
# 7517              Switzerland
# 11031                 Germany
# 11533                 Denmark
# 17808        Hong Kong, China
# 19565                 Ireland
# 20318                 Iceland
# 25589              Luxembourg
# 27848                   Malta
# 31111             Netherlands
# 31362                  Norway
# 34876                   Qatar
# 36633               Singapore
# 39394                  Sweden
# 42908                  Taiwan
# 44163           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2039
#
# 992      United Arab Emirates
# 2247                  Austria
# 3000                  Belgium
# 6263                   Brunei
# 7518              Switzerland
# 11032                 Germany
# 11534                 Denmark
# 17809        Hong Kong, China
# 19566                 Ireland
# 20319                 Iceland
# 25590              Luxembourg
# 27849                   Malta
# 31112             Netherlands
# 31363                  Norway
# 34877                   Qatar
# 36634               Singapore
# 39395                  Sweden
# 42909                  Taiwan
# 44164           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2040
#
# 993      United Arab Emirates
# 2248                  Austria
# 3001                  Belgium
# 6264                   Brunei
# 7519              Switzerland
# 11033                 Germany
# 11535                 Denmark
# 17810        Hong Kong, China
# 19567                 Ireland
# 20320                 Iceland
# 25591              Luxembourg
# 27850                   Malta
# 31113             Netherlands
# 31364                  Norway
# 34878                   Qatar
# 36635               Singapore
# 39396                  Sweden
# 42910                  Taiwan
# 44165           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2041
#
# 994      United Arab Emirates
# 2249                  Austria
# 3002                  Belgium
# 6265                   Brunei
# 7520              Switzerland
# 11034                 Germany
# 11536                 Denmark
# 17811        Hong Kong, China
# 19568                 Ireland
# 20321                 Iceland
# 25592              Luxembourg
# 27851                   Malta
# 31114             Netherlands
# 31365                  Norway
# 34879                   Qatar
# 36636               Singapore
# 39397                  Sweden
# 42911                  Taiwan
# 44166           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2042
#
# 995      United Arab Emirates
# 2250                  Austria
# 3003                  Belgium
# 6266                   Brunei
# 7521              Switzerland
# 11035                 Germany
# 11537                 Denmark
# 17812        Hong Kong, China
# 19569                 Ireland
# 20322                 Iceland
# 25593              Luxembourg
# 27852                   Malta
# 31115             Netherlands
# 31366                  Norway
# 34880                   Qatar
# 36637               Singapore
# 39398                  Sweden
# 42912                  Taiwan
# 44167           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2043
#
# 996      United Arab Emirates
# 2251                  Austria
# 3004                  Belgium
# 6267                   Brunei
# 7522              Switzerland
# 11036                 Germany
# 11538                 Denmark
# 17813        Hong Kong, China
# 19570                 Ireland
# 20323                 Iceland
# 25594              Luxembourg
# 27853                   Malta
# 31116             Netherlands
# 31367                  Norway
# 34881                   Qatar
# 36638               Singapore
# 39399                  Sweden
# 42913                  Taiwan
# 44168           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2044
#
# 997      United Arab Emirates
# 2252                  Austria
# 3005                  Belgium
# 6268                   Brunei
# 7523              Switzerland
# 11037                 Germany
# 11539                 Denmark
# 17814        Hong Kong, China
# 19571                 Ireland
# 20324                 Iceland
# 25595              Luxembourg
# 27854                   Malta
# 31117             Netherlands
# 31368                  Norway
# 34882                   Qatar
# 36639               Singapore
# 39400                  Sweden
# 42914                  Taiwan
# 44169           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2045
#
# 998      United Arab Emirates
# 2253                  Austria
# 3006                  Belgium
# 6269                   Brunei
# 7524              Switzerland
# 11038                 Germany
# 11540                 Denmark
# 17815        Hong Kong, China
# 19572                 Ireland
# 20325                 Iceland
# 25596              Luxembourg
# 27855                   Malta
# 31118             Netherlands
# 31369                  Norway
# 34883                   Qatar
# 36640               Singapore
# 39401                  Sweden
# 42915                  Taiwan
# 44170           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2046
#
# 999      United Arab Emirates
# 2254                  Austria
# 3007                  Belgium
# 6270                   Brunei
# 7525              Switzerland
# 11039                 Germany
# 11541                 Denmark
# 17816        Hong Kong, China
# 19573                 Ireland
# 20326                 Iceland
# 25597              Luxembourg
# 27856                   Malta
# 31119             Netherlands
# 31370                  Norway
# 34884                   Qatar
# 36641               Singapore
# 39402                  Sweden
# 42916                  Taiwan
# 44171           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2047
#
# 1000     United Arab Emirates
# 2255                  Austria
# 3008                  Belgium
# 6271                   Brunei
# 7526              Switzerland
# 11040                 Germany
# 11542                 Denmark
# 17817        Hong Kong, China
# 19574                 Ireland
# 20327                 Iceland
# 25598              Luxembourg
# 27857                   Malta
# 31120             Netherlands
# 31371                  Norway
# 34885                   Qatar
# 36642               Singapore
# 39403                  Sweden
# 42917                  Taiwan
# 44172           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2048
#
# 1001     United Arab Emirates
# 2256                  Austria
# 3009                  Belgium
# 6272                   Brunei
# 7527              Switzerland
# 11041                 Germany
# 11543                 Denmark
# 17818        Hong Kong, China
# 19575                 Ireland
# 20328                 Iceland
# 25599              Luxembourg
# 27858                   Malta
# 31121             Netherlands
# 31372                  Norway
# 34886                   Qatar
# 36643               Singapore
# 39404                  Sweden
# 42918                  Taiwan
# 44173           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2049
#
# 1002     United Arab Emirates
# 2257                  Austria
# 3010                  Belgium
# 6273                   Brunei
# 7528              Switzerland
# 11042                 Germany
# 11544                 Denmark
# 17819        Hong Kong, China
# 19576                 Ireland
# 20329                 Iceland
# 25600              Luxembourg
# 27859                   Malta
# 31122             Netherlands
# 31373                  Norway
# 34887                   Qatar
# 36644               Singapore
# 39405                  Sweden
# 42919                  Taiwan
# 44174           United States
# Name: country, dtype: object
# -------------------
#
# Year:  2050
#
# 1003     United Arab Emirates
# 2258                  Austria
# 3011                  Belgium
# 6274                   Brunei
# 7529              Switzerland
# 11043                 Germany
# 11545                 Denmark
# 17820        Hong Kong, China
# 19577                 Ireland
# 20330                 Iceland
# 25601              Luxembourg
# 27860                   Malta
# 31123             Netherlands
# 31374                  Norway
# 34888                   Qatar
# 36645               Singapore
# 39406                  Sweden
# 42920                  Taiwan
# 44175           United States
# Name: country, dtype: object
# -------------------

# %% [markdown]
# The same can be done using the apply method in a single step.
# So far we've seen that
# 1. The aggregate method, returns a single value for each group.
# 2. The transform method, returns a dataframe/series of the same size as the input group
#
# The apply method allows one to create custom functions that returns dataframes of **arbitrary sizes**
#
# `apply` takes a function as argument and passes each group as a dataframe/series to the function. This function must return a dataframe/series.
#
# In the code cell below, the lambda function `lambda x: x[x['income'] >= x['income'].quantile(0.9)]` filters each group and returns different size dataframes for each group.

# %%
gapminder.groupby(['year']).apply(lambda x: x[x['income'] >= x['income'].quantile(0.9)])
# Out:
#                   country  year          pop    income  lifeExp      Continent
# year
# 1800 1004       Argentina  1800     534000.0    1710.0     33.2  South America
#      2008         Austria  1800    3000000.0    2070.0     34.4         Europe
#      2761         Belgium  1800    3250000.0    2670.0     40.0         Europe
#      6024          Brunei  1800       2260.0    1690.0     29.2           Asia
#      7279     Switzerland  1800    1750000.0    2740.0     38.0         Europe
# ...                   ...   ...          ...       ...      ...            ...
# 2050 34888          Qatar  2050    3850000.0  161000.0     80.5           Asia
#      36645      Singapore  2050    6410000.0  164000.0     88.6           Asia
#      39406         Sweden  2050   11400000.0   88100.0     86.7         Europe
#      42920         Taiwan  2050   22400000.0  105000.0     84.9           Asia
#      44175  United States  2050  379000000.0  108000.0     83.5  North America
#
# [4800 rows x 6 columns]

# %% [markdown]
# ### Missing value treatment by imputation
#
# We've learnt about `imputation` in our previous lab on missing value treatment. Imputation is the process of replacing missing values with substituted values. You can also substitute values specific to a group . Let's take a look at the `Melbourne Housing dataset`
#
# |Variables|Description|
# |-|-|
# |Rooms| Number of rooms|
# |Price| Price in dollars|
# |Method| S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclosed. N/A - price or highest bid not available.|
# |Type| br - bedroom(s); h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.|
# |SellerG| Real Estate Agent|
# |Date| Date sold|
# |Distance| Distance from CBD|
# |Regionname| General Region (West, North West, North, North east …etc)|
# |Propertycount| Number of properties that exist in the suburb.|
# |Bedroom2 | Scraped # of Bedrooms (from different source)|
# |Bathroom| Number of Bathrooms|
# |Car| Number of carspots|
# |Landsize| Land Size|
# |BuildingArea| Building Size|
# |CouncilArea| Governing council for the area|

# %% [markdown]
# Let's load and explore the dataset.

# %%
source = sv_rep_path + 'melb_data.csv'
melb_df = pd.read_csv(source)
melb_df.shape
# Out:
# (13580, 21)

# %%
melb_df.head().T
# Out:
#                                    0                      1  \
# Suburb                    Abbotsford             Abbotsford
# Address                 85 Turner St        25 Bloomburg St
# Rooms                              2                      2
# Type                               h                      h
# Price                      1480000.0              1035000.0
# Method                             S                      S
# SellerG                       Biggin                 Biggin
# Date                       3/12/2016              4/02/2016
# Distance                         2.5                    2.5
# Postcode                      3067.0                 3067.0
# Bedroom2                         2.0                    2.0
# Bathroom                         1.0                    1.0
# Car                              1.0                    0.0
# Landsize                       202.0                  156.0
# BuildingArea                     NaN                   79.0
# YearBuilt                        NaN                 1900.0
# CouncilArea                    Yarra                  Yarra
# Lattitude                   -37.7996               -37.8079
# Longtitude                  144.9984               144.9934
# Regionname     Northern Metropolitan  Northern Metropolitan
# Propertycount                 4019.0                 4019.0
#
#                                    2                      3  \
# Suburb                    Abbotsford             Abbotsford
# Address                 5 Charles St       40 Federation La
# Rooms                              3                      3
# Type                               h                      h
# Price                      1465000.0               850000.0
# Method                            SP                     PI
# SellerG                       Biggin                 Biggin
# Date                       4/03/2017              4/03/2017
# Distance                         2.5                    2.5
# Postcode                      3067.0                 3067.0
# Bedroom2                         3.0                    3.0
# Bathroom                         2.0                    2.0
# Car                              0.0                    1.0
# Landsize                       134.0                   94.0
# BuildingArea                   150.0                    NaN
# YearBuilt                     1900.0                    NaN
# CouncilArea                    Yarra                  Yarra
# Lattitude                   -37.8093               -37.7969
# Longtitude                  144.9944               144.9969
# Regionname     Northern Metropolitan  Northern Metropolitan
# Propertycount                 4019.0                 4019.0
#
#                                    4
# Suburb                    Abbotsford
# Address                  55a Park St
# Rooms                              4
# Type                               h
# Price                      1600000.0
# Method                            VB
# SellerG                       Nelson
# Date                       4/06/2016
# Distance                         2.5
# Postcode                      3067.0
# Bedroom2                         3.0
# Bathroom                         1.0
# Car                              2.0
# Landsize                       120.0
# BuildingArea                   142.0
# YearBuilt                     2014.0
# CouncilArea                    Yarra
# Lattitude                   -37.8072
# Longtitude                  144.9941
# Regionname     Northern Metropolitan
# Propertycount                 4019.0

# %%
melb_df.tail().T
# Out:
#                                     13575                 13576  \
# Suburb                      Wheelers Hill          Williamstown
# Address                      12 Strada Cr         77 Merrett Dr
# Rooms                                   4                     3
# Type                                    h                     h
# Price                           1245000.0             1031000.0
# Method                                  S                    SP
# SellerG                             Barry              Williams
# Date                           26/08/2017            26/08/2017
# Distance                             16.7                   6.8
# Postcode                           3150.0                3016.0
# Bedroom2                              4.0                   3.0
# Bathroom                              2.0                   2.0
# Car                                   2.0                   2.0
# Landsize                            652.0                 333.0
# BuildingArea                          NaN                 133.0
# YearBuilt                          1981.0                1995.0
# CouncilArea                           NaN                   NaN
# Lattitude                       -37.90562             -37.85927
# Longtitude                      145.16761             144.87904
# Regionname     South-Eastern Metropolitan  Western Metropolitan
# Propertycount                      7392.0                6380.0
#
#                               13577                 13578  \
# Suburb                 Williamstown          Williamstown
# Address                 83 Power St          96 Verdon St
# Rooms                             3                     4
# Type                              h                     h
# Price                     1170000.0             2500000.0
# Method                            S                    PI
# SellerG                       Raine               Sweeney
# Date                     26/08/2017            26/08/2017
# Distance                        6.8                   6.8
# Postcode                     3016.0                3016.0
# Bedroom2                        3.0                   4.0
# Bathroom                        2.0                   1.0
# Car                             4.0                   5.0
# Landsize                      436.0                 866.0
# BuildingArea                    NaN                 157.0
# YearBuilt                    1997.0                1920.0
# CouncilArea                     NaN                   NaN
# Lattitude                 -37.85274             -37.85908
# Longtitude                144.88738             144.89299
# Regionname     Western Metropolitan  Western Metropolitan
# Propertycount                6380.0                6380.0
#
#                               13579
# Suburb                   Yarraville
# Address                  6 Agnes St
# Rooms                             4
# Type                              h
# Price                     1285000.0
# Method                           SP
# SellerG                     Village
# Date                     26/08/2017
# Distance                        6.3
# Postcode                     3013.0
# Bedroom2                        4.0
# Bathroom                        1.0
# Car                             1.0
# Landsize                      362.0
# BuildingArea                  112.0
# YearBuilt                    1920.0
# CouncilArea                     NaN
# Lattitude                 -37.81188
# Longtitude                144.88449
# Regionname     Western Metropolitan
# Propertycount                6543.0

# %%
import missingno as msno
msno.matrix(melb_df)
plt.show()
msno.bar(melb_df)

plt.show()

# %% [markdown]
# For the purpose of this exercise let's assume that 200 random values of the Bathroom variable are missing.

# %%
# remove 200 values from the Bathroom column 
melb_df.loc[np.random.permutation(melb_df.index)[:200], 'Bathroom']= np.NaN

# %%
msno.matrix(melb_df)
plt.show()
msno.bar(melb_df)

plt.show()

# %% [markdown]
# Our goal is to impute the missing values of the Bathroom column by it's median. However we do not want to do it with the overall median. Let's say we make an educated guess that the number of bathrooms closely relates to the number of rooms and the type of housing (Or check the correlation between variables). Is there a way to use this information while dealing with missing values?
#
#
# We can group the dataset by `Rooms` and `Type`. We can then fill missing values with the median of each group as shown below

# %%
# imputation my median
def fill_median(x):
    median = x.median()
    # fill missing values with median
    return(x.fillna(median))

# SPLIT
#1 groupby Rooms and Type
#2 subset the Bathroom column

grouped = melb_df.groupby(['Rooms', 'Type'])['Bathroom']

for name, group in grouped:
    print(f'group: {name}')
    print(f'size: {group.shape}')

# APPLY-COMBINE
#3 transform the column by a function
melb_df['Bathroom_filled'] = grouped.transform(fill_median)


melb_df[['Bathroom', 'Bathroom_filled']]
# Out:
# group: (1, 'h')
# size: (58,)
# group: (1, 't')
# size: (11,)
# group: (1, 'u')
# size: (612,)
# group: (2, 'h')
# size: (1398,)
# group: (2, 't')
# size: (319,)
# group: (2, 'u')
# size: (1931,)
# group: (3, 'h')
# size: (4801,)
# group: (3, 't')
# size: (629,)
# group: (3, 'u')
# size: (451,)
# group: (4, 'h')
# size: (2517,)
# group: (4, 't')
# size: (150,)
# group: (4, 'u')
# size: (21,)
# group: (5, 'h')
# size: (591,)
# group: (5, 't')
# size: (5,)
# group: (6, 'h')
# size: (66,)
# group: (6, 'u')
# size: (1,)
# group: (7, 'h')
# size: (10,)
# group: (8, 'h')
# size: (7,)
# group: (8, 'u')
# size: (1,)
# group: (10, 'h')
# size: (1,)
#        Bathroom  Bathroom_filled
# 0           1.0              1.0
# 1           1.0              1.0
# 2           2.0              2.0
# 3           2.0              2.0
# 4           1.0              1.0
# ...         ...              ...
# 13575       2.0              2.0
# 13576       2.0              2.0
# 13577       2.0              2.0
# 13578       1.0              1.0
# 13579       1.0              1.0
#
# [13580 rows x 2 columns]

# %% [markdown]
# Let's specifically look at the rows that have missing values in the Bathroom column

# %%
filter = melb_df['Bathroom'].isna()
filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Name: Bathroom, Length: 13580, dtype: bool

# %%
melb_df[filter][['Type','Rooms','Bathroom','Bathroom_filled']]
# Out:
#       Type  Rooms  Bathroom  Bathroom_filled
# 63       h      4       NaN              2.0
# 99       h      2       NaN              1.0
# 102      h      3       NaN              1.0
# 168      h      3       NaN              1.0
# 169      u      2       NaN              1.0
# ...    ...    ...       ...              ...
# 13106    h      3       NaN              1.0
# 13263    t      3       NaN              2.0
# 13405    h      5       NaN              3.0
# 13435    h      3       NaN              1.0
# 13475    h      3       NaN              1.0
#
# [200 rows x 4 columns]

# %% [markdown]
# We observe that the missing values are filled differently for the different groups

# %% [markdown]
# # Summary
#
# We've learnt about
# 1. the split-apply-combine technique with groupby
# 2. Aggregate
# 3. Transform
# 4. Apply

# %% [markdown]
# ## References
#
# * <a href="https://www.researchgate.net/publication/51028554_The_Split-Apply-Combine_Strategy_for_Data_Analysis"> **"The Split-Apply-Combine Strategy for Data Analysis"**. </a>
#
# * <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html"> The pandas user-guide's section on the `DataFrame.groupby()`.
#
# * <a href="https://github.com/supportvectors/">SupportVectors git repositories. </a>
