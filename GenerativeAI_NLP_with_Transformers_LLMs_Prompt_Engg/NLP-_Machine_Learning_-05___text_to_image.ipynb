# %%
# %run supportvectors-common.ipynb
# Out:
# <!-- Many of the styles here are inspired by:
#     https://towardsdatascience.com/10-practical-tips-you-need-to-know-to-personalize-jupyter-notebook-fbd202777e20
#
#
#     On the author's local machine, these exist in the custom.css file. However, in order to keep uniform look and feel,
#     and at the request of participants, I have added it to this common import-file here.
#
#     -->
#
# <link href="https://fonts.googleapis.com/css?family=Lora:400,700|Montserrat:300" rel="stylesheet">
#
# <link href="https://fonts.googleapis.com/css2?family=Crimson+Pro&family=Literata&display=swap" rel="stylesheet">
# <style>
#
#
# #ipython_notebook::before{
#  content:"NLP with Transformers";
#         color: white;
#         font-weight: bold;
#         text-transform: uppercase;
#         font-family: 'Lora',serif;
#         font-size:16pt;
#         margin-bottom:15px;
#         margin-top:15px;
#
# }
# body > #header {
#     #background: #D15555;
#     background: linear-gradient(to bottom, indianred 0%, #fff 100%);
#     opacity: 0.8;
#
# }
#
#
# .navbar-default .navbar-nav > li > a, #kernel_indicator {
#     color: white;
#     transition: all 0.25s;
#     font-size:10pt;
#     font-family: sans-serif;
#     font-weight:normal;
# }
# .navbar-default {
#     padding-left:100px;
#     background: none;
#     border: none;
# }
#
#
# body > menubar-container {
#     background-color: wheat;
# }
# #ipython_notebook img{
#     display:block;
#
#     background: url("https://www.supportvectors.com/wp-content/uploads/2016/03/logo-poster-smaller.png") no-repeat;
#     background-size: contain;
#
#     padding-left: 600px;
#     padding-right: 100px;
#
#     -moz-box-sizing: border-box;
#     box-sizing: border-box;
# }
#
#
#
# body {
#  #font-family:  'Literata', serif;
#     font-family:'Lora', san-serif;
#     text-align: justify;
#     font-weight: 400;
#     font-size: 12pt;
# }
#
# iframe{
#     width:100%;
#     min-height:600px;
# }
#
# h1, h2, h3, h4, h5, h6 {
# # font-family: 'Montserrat', sans-serif;
#  font-family:'Lora', serif;
#  font-weight: 200;
#  text-transform: uppercase;
#  color: #EC7063 ;
# }
#
# h2 {
#     color: #000080;
# }
#
# .checkpoint_status, .autosave_status {
#     color:wheat;
# }
#
# #notebook_name {
#     font-weight: 600;
#     font-size:20pt;
#     text-variant:uppercase;
#     color: wheat;
#     margin-right:20px;
#     margin-left:-500px;
# }
# #notebook_name:hover {
# background-color: salmon;
# }
#
#
# .dataframe { /* dataframe atau table */
#     background: white;
#     box-shadow: 0px 1px 2px #bbb;
# }
# .dataframe thead th, .dataframe tbody td {
#     text-align: center;
#     padding: 1em;
# }
#
# .checkpoint_status, .autosave_status {
#     color:wheat;
# }
#
# .output {
#     align-items: center;
# }
#
# div.cell {
#     transition: all 0.25s;
#     border: none;
#     position: relative;
#     top: 0;
# }
# div.cell.selected, div.cell.selected.jupyter-soft-selected {
#     border: none;
#     background: transparent;
#     box-shadow: 0 6px 18px #aaa;
#     z-index: 10;
#     top: -10px;
# }
# .CodeMirror pre, .CodeMirror-dialog, .CodeMirror-dialog .CodeMirror-search-field, .terminal-app .terminal {
#     font-family: 'Hack' , serif;
#     font-weight: 500;
#     font-size: 14pt;
# }
#
#
#
# </style>
# <div style="color:#aaa;font-size:8pt">
# <hr/>
#
#  </blockquote>
#  <hr/>
# </div>

# %% [markdown]
# ## Text to Image

# %%
# !pip install diffusers transformers accelerate scipy safetensors xformers --upgrade
# Out:
# Collecting diffusers
#   Using cached diffusers-0.14.0-py3-none-any.whl (737 kB)
# Collecting transformers
#   Using cached transformers-4.27.4-py3-none-any.whl (6.8 MB)
# Collecting accelerate
#   Using cached accelerate-0.18.0-py3-none-any.whl (215 kB)
# Requirement already satisfied: scipy in /home/asif/anaconda3/lib/python3.9/site-packages (1.9.3)
# Collecting scipy
#   Using cached scipy-1.10.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Collecting safetensors
#   Using cached safetensors-0.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting xformers
#   Using cached xformers-0.0.18-cp39-cp39-manylinux2014_x86_64.whl (123.8 MB)
# Requirement already satisfied: regex!=2019.12.17 in /home/asif/anaconda3/lib/python3.9/site-packages (from diffusers) (2021.11.10)
# Requirement already satisfied: importlib-metadata in /home/asif/anaconda3/lib/python3.9/site-packages (from diffusers) (4.11.3)
# Requirement already satisfied: numpy in /home/asif/anaconda3/lib/python3.9/site-packages (from diffusers) (1.23.5)
# Requirement already satisfied: filelock in /home/asif/anaconda3/lib/python3.9/site-packages (from diffusers) (3.6.0)
# Requirement already satisfied: requests in /home/asif/anaconda3/lib/python3.9/site-packages (from diffusers) (2.28.1)
# Collecting huggingface-hub>=0.10.0
#   Using cached huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
# Requirement already satisfied: Pillow in /home/asif/anaconda3/lib/python3.9/site-packages (from diffusers) (9.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/asif/anaconda3/lib/python3.9/site-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
# Requirement already satisfied: packaging>=20.0 in /home/asif/anaconda3/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /home/asif/anaconda3/lib/python3.9/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: psutil in /home/asif/anaconda3/lib/python3.9/site-packages (from accelerate) (5.9.0)
# Collecting torch>=1.4.0
#   Using cached torch-2.0.0-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
# Collecting pyre-extensions==0.0.23
#   Using cached pyre_extensions-0.0.23-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions in /home/asif/anaconda3/lib/python3.9/site-packages (from pyre-extensions==0.0.23->xformers) (4.3.0)
# Collecting typing-inspect
#   Using cached typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: jinja2 in /home/asif/anaconda3/lib/python3.9/site-packages (from torch>=1.4.0->accelerate) (3.0.3)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Requirement already satisfied: sympy in /home/asif/anaconda3/lib/python3.9/site-packages (from torch>=1.4.0->accelerate) (1.10.1)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-nccl-cu11==2.14.3
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 8.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Requirement already satisfied: networkx in /home/asif/anaconda3/lib/python3.9/site-packages (from torch>=1.4.0->accelerate) (2.8.4)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 7.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: wheel in /home/asif/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4.0->accelerate) (0.37.1)
# Requirement already satisfied: setuptools in /home/asif/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4.0->accelerate) (60.10.0)
# Collecting lit
#   Downloading lit-16.0.0.tar.gz (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cmake
#   Downloading cmake-3.26.1-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 10.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/asif/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /home/asif/anaconda3/lib/python3.9/site-packages (from importlib-metadata->diffusers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asif/anaconda3/lib/python3.9/site-packages (from requests->diffusers) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asif/anaconda3/lib/python3.9/site-packages (from requests->diffusers) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/asif/anaconda3/lib/python3.9/site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/asif/anaconda3/lib/python3.9/site-packages (from requests->diffusers) (3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asif/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.4.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/asif/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.4.0->accelerate) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/asif/anaconda3/lib/python3.9/site-packages (from typing-inspect->pyre-extensions==0.0.23->xformers) (0.4.3)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.0-py3-none-any.whl size=93600 sha256=144e9f6b5706ec9775639c62b9279cf9b53c1c1261340f01fb6e49e78c2eaaa2
#   Stored in directory: /home/asif/.cache/pip/wheels/c7/ee/80/1520ca86c3557f70e5504b802072f7fc3b0e2147f376b133ed
# Successfully built lit
# Installing collected packages: tokenizers, safetensors, lit, cmake, typing-inspect, scipy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, pyre-extensions, nvidia-cusolver-cu11, nvidia-cudnn-cu11, huggingface-hub, transformers, diffusers, triton, torch, xformers, accelerate
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.0.0 requires scipy<1.10,>=1.4.1, but you have scipy 1.10.1 which is incompatible.
# dtale 2.12.2 requires scipy==1.9.3; python_version >= "3.8", but you have scipy 1.10.1 which is incompatible.
# Successfully installed accelerate-0.18.0 cmake-3.26.1 diffusers-0.14.0 huggingface-hub-0.13.3 lit-16.0.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 pyre-extensions-0.0.23 safetensors-0.3.0 scipy-1.10.1 tokenizers-0.13.2 torch-2.0.0 transformers-4.27.4 triton-2.0.0 typing-inspect-0.8.0 xformers-0.0.18

# %%
from diffusers import DiffusionPipeline

pipeline = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
#pipeline.to("cuda")
image = pipeline("An image of a squirrel in Picasso style").images[0]
image.save('squirrel-picasso.png')
image
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from diffusers import DiffusionPipeline, EulerDiscreteScheduler, DPMSolverMultistepScheduler

repo_id = "runwayml/stable-diffusion-v1-5"

scheduler = EulerDiscreteScheduler.from_pretrained(repo_id, subfolder="scheduler")
# or
# scheduler = DPMSolverMultistepScheduler.from_pretrained(repo_id, subfolder="scheduler")

stable_diffusion = DiffusionPipeline.from_pretrained(repo_id, scheduler=scheduler)

# if you want to use the gpu
#torch.cuda.empty_cache()
#stable_diffusion.to("cuda")

image = stable_diffusion("Monkey on a boat in a stormy sea.").images[0]
image.save('monkey.png')
image
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from diffusers import DiffusionPipeline, EulerDiscreteScheduler, DPMSolverMultistepScheduler

repo_id = "runwayml/stable-diffusion-v1-5"

scheduler = EulerDiscreteScheduler.from_pretrained(repo_id, subfolder="scheduler")
# or
# scheduler = DPMSolverMultistepScheduler.from_pretrained(repo_id, subfolder="scheduler")

stable_diffusion = DiffusionPipeline.from_pretrained(repo_id, scheduler=scheduler)

# if you want to use the gpu
#torch.cuda.empty_cache()
#stable_diffusion.to("cuda")

image = stable_diffusion("Cow reading a book, while sitting on moon rock.").images[0]
image.save('cow.png')
image
# Out:
# Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading (…)ain/model_index.json:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)819/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)d819/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# /home/asif/anaconda3/lib/python3.9/site-packages/transformers/modeling_utils.py:402: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   with safe_open(checkpoint_file, framework="pt") as f:
# /home/asif/anaconda3/lib/python3.9/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /home/asif/anaconda3/lib/python3.9/site-packages/torch/storage.py:899: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = cls(wrap_storage=untyped_storage)
# /home/asif/anaconda3/lib/python3.9/site-packages/safetensors/torch.py:99: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   with safe_open(filename, framework="pt", device=device) as f:
# /home/asif/anaconda3/lib/python3.9/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
